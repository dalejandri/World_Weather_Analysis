# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random 1500 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. unpack our lat_lngs zip object into a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
# The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 799

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Weather": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | salamiyah
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | vitoria
# Processing Record 7 of Set 1 | sidi ali
# Processing Record 8 of Set 1 | attawapiskat
# Processing Record 9 of Set 1 | panacan
# Processing Record 10 of Set 1 | pasir gudang
# Processing Record 11 of Set 1 | galle
# Processing Record 12 of Set 1 | marawi
# Processing Record 13 of Set 1 | salamanca
# Processing Record 14 of Set 1 | atherton
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | ijaki
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | teacapan
# Processing Record 19 of Set 1 | tbilisskaya
# Processing Record 20 of Set 1 | ambilobe
# Processing Record 21 of Set 1 | mahanoro
# Processing Record 22 of Set 1 | gra liyia
# Processing Record 23 of Set 1 | hit
# Processing Record 24 of Set 1 | letlhakane
# Processing Record 25 of Set 1 | taolanaro
# Processing Record 26 of Set 1 | sentyabrskiy
# Processing Record 27 of Set 1 | limbang
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | kudahuvadhoo
# Processing Record 32 of Set 1 | florence
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | puerto escondido
# Processing Record 35 of Set 1 | boyabat
# Processing Record 36 of Set 1 | barentsburg
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | northam
# Processing Record 40 of Set 1 | illoqqortoormiut
# Processing Record 41 of Set 1 | miracatu
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | chulman
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | villamontes
# Processing Record 5 of Set 2 | jamnagar
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | kurilsk
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | thinadhoo
# Processing Record 10 of Set 2 | alofi
# Processing Record 11 of Set 2 | prado
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | barcelos
# Processing Record 14 of Set 2 | galesong
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | launceston
# Processing Record 19 of Set 2 | francistown
# Processing Record 20 of Set 2 | sainte-maxime
# Processing Record 21 of Set 2 | stoyba
# Processing Record 22 of Set 2 | jaca
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | louisbourg
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | tamale
# Processing Record 28 of Set 2 | nelson bay
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | petrozavodsk
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | chavakkad
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | umea
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | guerrero negro
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | manokwari
# Processing Record 44 of Set 2 | machiques
# Processing Record 45 of Set 2 | shingu
# Processing Record 46 of Set 2 | sungaipenuh
# Processing Record 47 of Set 2 | taree
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | phalaborwa
# Processing Record 50 of Set 2 | dunedin
# Processing Record 1 of Set 3 | amapa
# Processing Record 2 of Set 3 | baykit
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | santa maria
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | tazmalt
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | vila franca do campo
# Processing Record 10 of Set 3 | astoria
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | hovd
# Processing Record 14 of Set 3 | esfahan
# Processing Record 15 of Set 3 | tutoia
# Processing Record 16 of Set 3 | touros
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | stodolishche
# Processing Record 26 of Set 3 | djambala
# Processing Record 27 of Set 3 | bereznik
# Processing Record 28 of Set 3 | kurchum
# Processing Record 29 of Set 3 | ponta delgada
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | dingle
# Processing Record 32 of Set 3 | camacha
# Processing Record 33 of Set 3 | brigantine
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | swellendam
# Processing Record 36 of Set 3 | puerto maldonado
# Processing Record 37 of Set 3 | kununurra
# Processing Record 38 of Set 3 | broome
# Processing Record 39 of Set 3 | buraydah
# Processing Record 40 of Set 3 | gat
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | saint-joseph
# Processing Record 43 of Set 3 | marcona
# Processing Record 44 of Set 3 | nenjiang
# Processing Record 45 of Set 3 | opuwo
# Processing Record 46 of Set 3 | veraval
# Processing Record 47 of Set 3 | hualmay
# Processing Record 48 of Set 3 | kathu
# Processing Record 49 of Set 3 | sulphur
# Processing Record 50 of Set 3 | breznik
# Processing Record 1 of Set 4 | jenison
# Processing Record 2 of Set 4 | lasa
# Processing Record 3 of Set 4 | rexburg
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | cherskiy
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | kalaleh
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | asayita
# Processing Record 13 of Set 4 | palauig
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | bluff
# Processing Record 17 of Set 4 | autazes
# Processing Record 18 of Set 4 | palabuhanratu
# Processing Record 19 of Set 4 | riyadh
# Processing Record 20 of Set 4 | kozhva
# Processing Record 21 of Set 4 | aragarcas
# Processing Record 22 of Set 4 | dauriya
# Processing Record 23 of Set 4 | buenavista
# Processing Record 24 of Set 4 | saint george
# Processing Record 25 of Set 4 | alta
# Processing Record 26 of Set 4 | key largo
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | mayo
# Processing Record 29 of Set 4 | riese
# Processing Record 30 of Set 4 | najran
# Processing Record 31 of Set 4 | antsohihy
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | hong gai
# Processing Record 35 of Set 4 | toliary
# Processing Record 36 of Set 4 | kiama
# Processing Record 37 of Set 4 | antalaha
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | kailua
# Processing Record 40 of Set 4 | bredasdorp
# Processing Record 41 of Set 4 | portsoy
# Processing Record 42 of Set 4 | tumannyy
# Processing Record 43 of Set 4 | sovetskiy
# Processing Record 44 of Set 4 | novyy urgal
# Processing Record 45 of Set 4 | vuktyl
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | surgut
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | lexington
# Processing Record 50 of Set 4 | codrington
# Processing Record 1 of Set 5 | mwene-ditu
# Processing Record 2 of Set 5 | homer
# Processing Record 3 of Set 5 | aykhal
# Processing Record 4 of Set 5 | batagay
# Processing Record 5 of Set 5 | belmonte
# Processing Record 6 of Set 5 | panaba
# Processing Record 7 of Set 5 | puerto gaitan
# Processing Record 8 of Set 5 | wajima
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | vanimo
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | salinas
# Processing Record 14 of Set 5 | haibowan
# Processing Record 15 of Set 5 | sept-iles
# Processing Record 16 of Set 5 | zyryanka
# Processing Record 17 of Set 5 | barranca
# Processing Record 18 of Set 5 | caronport
# Processing Record 19 of Set 5 | charters towers
# Processing Record 20 of Set 5 | clyde river
# Processing Record 21 of Set 5 | katangli
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | penzance
# Processing Record 24 of Set 5 | nawabganj
# Processing Record 25 of Set 5 | iquique
# Processing Record 26 of Set 5 | noumea
# Processing Record 27 of Set 5 | tiszasuly
# Processing Record 28 of Set 5 | krasnoarmeysk
# Processing Record 29 of Set 5 | komsomolskiy
# Processing Record 30 of Set 5 | santa eulalia del rio
# Processing Record 31 of Set 5 | saint-philippe
# Processing Record 32 of Set 5 | medicine hat
# Processing Record 33 of Set 5 | skagastrond
# Processing Record 34 of Set 5 | muroto
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | portobelo
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | avera
# Processing Record 39 of Set 5 | paamiut
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | oussouye
# Processing Record 42 of Set 5 | tanshui
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | samusu
# Processing Record 46 of Set 5 | batagay-alyta
# Processing Record 47 of Set 5 | bambanglipuro
# Processing Record 48 of Set 5 | ponta do sol
# Processing Record 49 of Set 5 | takaka
# Processing Record 50 of Set 5 | saint-augustin
# Processing Record 1 of Set 6 | mount gambier
# Processing Record 2 of Set 6 | ola
# Processing Record 3 of Set 6 | humboldt
# Processing Record 4 of Set 6 | makakilo city
# Processing Record 5 of Set 6 | pevek
# Processing Record 6 of Set 6 | fasa
# Processing Record 7 of Set 6 | shenjiamen
# Processing Record 8 of Set 6 | francheville
# Processing Record 9 of Set 6 | getulio vargas
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | lerwick
# Processing Record 12 of Set 6 | mende
# Processing Record 13 of Set 6 | narrabri
# Processing Record 14 of Set 6 | nacozari
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | fairbanks
# Processing Record 17 of Set 6 | belushya guba
# Processing Record 18 of Set 6 | salalah
# Processing Record 19 of Set 6 | jiddah
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | shubarshi
# Processing Record 22 of Set 6 | tessalit
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | burgeo
# Processing Record 25 of Set 6 | narsaq
# Processing Record 26 of Set 6 | celestun
# Processing Record 27 of Set 6 | sarangani
# Processing Record 28 of Set 6 | bom jesus da lapa
# Processing Record 29 of Set 6 | pedasi
# Processing Record 30 of Set 6 | porto novo
# Processing Record 31 of Set 6 | sabha
# Processing Record 32 of Set 6 | jackson
# Processing Record 33 of Set 6 | umzimvubu
# Processing Record 34 of Set 6 | coquimbo
# Processing Record 35 of Set 6 | alma
# Processing Record 36 of Set 6 | tongliao
# Processing Record 37 of Set 6 | krasnyy oktyabr
# Processing Record 38 of Set 6 | dudinka
# Processing Record 39 of Set 6 | hammerfest
# Processing Record 40 of Set 6 | iskateley
# Processing Record 41 of Set 6 | soe
# Processing Record 42 of Set 6 | collie
# Processing Record 43 of Set 6 | muzhi
# Processing Record 44 of Set 6 | wuzhou
# Processing Record 45 of Set 6 | kaka
# Processing Record 46 of Set 6 | jaciara
# Processing Record 47 of Set 6 | waipawa
# Processing Record 48 of Set 6 | bodden town
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 50 of Set 6 | peleduy
# Processing Record 1 of Set 7 | alexandria
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | eureka
# Processing Record 4 of Set 7 | santa luzia
# Processing Record 5 of Set 7 | lakhipur
# Processing Record 6 of Set 7 | diffa
# Processing Record 7 of Set 7 | port macquarie
# Processing Record 8 of Set 7 | kamenka
# Processing Record 9 of Set 7 | inuvik
# Processing Record 10 of Set 7 | fort nelson
# Processing Record 11 of Set 7 | kamenskoye
# Processing Record 12 of Set 7 | svetlyy
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | auki
# Processing Record 15 of Set 7 | saleaula
# Processing Record 16 of Set 7 | udachnyy
# Processing Record 17 of Set 7 | wamba
# Processing Record 18 of Set 7 | sistranda
# Processing Record 19 of Set 7 | kidal
# Processing Record 20 of Set 7 | le port
# Processing Record 21 of Set 7 | eyl
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | magadan
# Processing Record 24 of Set 7 | marmashen
# Processing Record 25 of Set 7 | marathon
# Processing Record 26 of Set 7 | andenes
# Processing Record 27 of Set 7 | tura
# Processing Record 28 of Set 7 | tsihombe
# Processing Record 29 of Set 7 | torbay
# Processing Record 30 of Set 7 | termoli
# Processing Record 31 of Set 7 | san vicente
# Processing Record 32 of Set 7 | surab
# Processing Record 33 of Set 7 | santa lucia
# Processing Record 34 of Set 7 | los llanos de aridane
# Processing Record 35 of Set 7 | kil
# Processing Record 36 of Set 7 | berlevag
# Processing Record 37 of Set 7 | buchanan
# Processing Record 38 of Set 7 | karasjok
# Processing Record 39 of Set 7 | richards bay
# Processing Record 40 of Set 7 | khonuu
# Processing Record 41 of Set 7 | rawson
# Processing Record 42 of Set 7 | taltal
# Processing Record 43 of Set 7 | leo
# Processing Record 44 of Set 7 | kuching
# Processing Record 45 of Set 7 | diego de almagro
# Processing Record 46 of Set 7 | kuche
# Processing Record 47 of Set 7 | matagami
# Processing Record 48 of Set 7 | umm durman
# Processing Record 49 of Set 7 | wageningen
# Processing Record 50 of Set 7 | erdenet
# Processing Record 1 of Set 8 | huarmey
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | north bend
# Processing Record 4 of Set 8 | kangasala
# Processing Record 5 of Set 8 | moree
# Processing Record 6 of Set 8 | maloshuyka
# Processing Record 7 of Set 8 | lethem
# Processing Record 8 of Set 8 | sioux lookout
# Processing Record 9 of Set 8 | padang
# Processing Record 10 of Set 8 | port hedland
# Processing Record 11 of Set 8 | marabba
# Processing Record 12 of Set 8 | colonia
# Processing Record 13 of Set 8 | kholodnyy
# Processing Record 14 of Set 8 | pudozh
# Processing Record 15 of Set 8 | lakes entrance
# Processing Record 16 of Set 8 | san buenaventura
# Processing Record 17 of Set 8 | hillsboro
# Processing Record 18 of Set 8 | atbasar
# Processing Record 19 of Set 8 | vardo
# Processing Record 20 of Set 8 | san angelo
# Processing Record 21 of Set 8 | kahului
# Processing Record 22 of Set 8 | tokmak
# Processing Record 23 of Set 8 | port blair
# Processing Record 24 of Set 8 | mys shmidta
# Processing Record 25 of Set 8 | bratsk
# Processing Record 26 of Set 8 | buala
# Processing Record 27 of Set 8 | shankargarh
# Processing Record 28 of Set 8 | korla
# Processing Record 29 of Set 8 | bolshegrivskoye
# Processing Record 30 of Set 8 | norman wells
# Processing Record 31 of Set 8 | khandagayty
# Processing Record 32 of Set 8 | acapulco
# Processing Record 33 of Set 8 | cabo san lucas
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | nizwa
# Processing Record 36 of Set 8 | margate
# Processing Record 37 of Set 8 | nacimiento
# Processing Record 38 of Set 8 | shenkursk
# Processing Record 39 of Set 8 | sao joao da barra
# Processing Record 40 of Set 8 | mokhsogollokh
# Processing Record 41 of Set 8 | kakonko
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | cheyenne
# Processing Record 44 of Set 8 | esperance
# Processing Record 45 of Set 8 | karaul
# Processing Record 46 of Set 8 | lewisporte
# Processing Record 47 of Set 8 | tomatlan
# Processing Record 48 of Set 8 | kaitangata
# Processing Record 49 of Set 8 | erenhot
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | chute-aux-outardes
# Processing Record 2 of Set 9 | roura
# Processing Record 3 of Set 9 | port shepstone
# Processing Record 4 of Set 9 | chissamba
# Processing Record 5 of Set 9 | grand-lahou
# Processing Record 6 of Set 9 | cidreira
# Processing Record 7 of Set 9 | languyan
# Processing Record 8 of Set 9 | presidente medici
# Processing Record 9 of Set 9 | vaitupu
# Processing Record 10 of Set 9 | bonthe
# Processing Record 11 of Set 9 | grootegast
# Processing Record 12 of Set 9 | san cosme y damian
# Processing Record 13 of Set 9 | dhidhdhoo
# Processing Record 14 of Set 9 | cabedelo
# Processing Record 15 of Set 9 | coos bay
# Processing Record 16 of Set 9 | champerico
# Processing Record 17 of Set 9 | nangomba
# Processing Record 18 of Set 9 | kombissiri
# Processing Record 19 of Set 9 | cap malheureux
# Processing Record 20 of Set 9 | cumaribo
# Processing Record 21 of Set 9 | yarovoye
# Processing Record 22 of Set 9 | tevaitoa
# Processing Record 23 of Set 9 | whitianga
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | ostrovnoy
# Processing Record 26 of Set 9 | gamba
# Processing Record 27 of Set 9 | husavik
# Processing Record 28 of Set 9 | the valley
# Processing Record 29 of Set 9 | igarka
# Processing Record 30 of Set 9 | pyapon
# Processing Record 31 of Set 9 | beloha
# Processing Record 32 of Set 9 | napier
# Processing Record 33 of Set 9 | uribia
# Processing Record 34 of Set 9 | tiksi
# Processing Record 35 of Set 9 | san juan de los morros
# Processing Record 36 of Set 9 | lacombe
# Processing Record 37 of Set 9 | santiago del estero
# Processing Record 38 of Set 9 | pauini
# Processing Record 39 of Set 9 | fukue
# Processing Record 40 of Set 9 | zambezi
# Processing Record 41 of Set 9 | tilichiki
# Processing Record 42 of Set 9 | puerto carreno
# Processing Record 43 of Set 9 | teya
# Processing Record 44 of Set 9 | ngukurr
# Processing Record 45 of Set 9 | amderma
# Processing Record 46 of Set 9 | fort saint john
# Processing Record 47 of Set 9 | calvinia
# Processing Record 48 of Set 9 | kaeo
# Processing Record 49 of Set 9 | fenyi
# Processing Record 50 of Set 9 | prince rupert
# Processing Record 1 of Set 10 | santa rosa
# Processing Record 2 of Set 10 | gisborne
# Processing Record 3 of Set 10 | markivka
# Processing Record 4 of Set 10 | guantanamo
# Processing Record 5 of Set 10 | grand river south east
# Processing Record 6 of Set 10 | provideniya
# Processing Record 7 of Set 10 | kiunga
# Processing Record 8 of Set 10 | cam pha
# Processing Record 9 of Set 10 | camuy
# Processing Record 10 of Set 10 | darhan
# Processing Record 11 of Set 10 | inta
# Processing Record 12 of Set 10 | sofiysk
# Processing Record 13 of Set 10 | sahrak
# Processing Record 14 of Set 10 | north myrtle beach
# Processing Record 15 of Set 10 | kaga
# Processing Record 16 of Set 10 | laiwu
# Processing Record 17 of Set 10 | kieta
# Processing Record 18 of Set 10 | oranjemund
# Processing Record 19 of Set 10 | meulaboh
# Processing Record 20 of Set 10 | xining
# Processing Record 21 of Set 10 | westport
# Processing Record 22 of Set 10 | ust-barguzin
# Processing Record 23 of Set 10 | pastavy
# Processing Record 24 of Set 10 | sorvag
# Processing Record 25 of Set 10 | weyburn
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | jining
# Processing Record 28 of Set 10 | wad rawah
# Processing Record 29 of Set 10 | carlagan
# Processing Record 30 of Set 10 | kushmurun
# Processing Record 31 of Set 10 | fort saint james
# Processing Record 32 of Set 10 | yakeshi
# Processing Record 33 of Set 10 | omboue
# Processing Record 34 of Set 10 | barawe
# Processing Record 35 of Set 10 | utiroa
# Processing Record 36 of Set 10 | college
# Processing Record 37 of Set 10 | jabiru
# Processing Record 38 of Set 10 | pochutla
# Processing Record 39 of Set 10 | jhelum
# Processing Record 40 of Set 10 | ankazoabo
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | mersing
# Processing Record 43 of Set 10 | bhadravati
# Processing Record 44 of Set 10 | mahon
# Processing Record 45 of Set 10 | ushumun
# Processing Record 46 of Set 10 | chicama
# Processing Record 47 of Set 10 | crixas
# Processing Record 48 of Set 10 | tidore
# Processing Record 49 of Set 10 | nalut
# Processing Record 50 of Set 10 | voh
# Processing Record 1 of Set 11 | yar-sale
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | tukrah
# Processing Record 4 of Set 11 | olinda
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | sur
# Processing Record 7 of Set 11 | albemarle
# Processing Record 8 of Set 11 | mahaicony
# Processing Record 9 of Set 11 | myitkyina
# Processing Record 10 of Set 11 | inhambane
# Processing Record 11 of Set 11 | maniitsoq
# Processing Record 12 of Set 11 | sharjah
# Processing Record 13 of Set 11 | hobyo
# Processing Record 14 of Set 11 | seoul
# Processing Record 15 of Set 11 | tafo
# Processing Record 16 of Set 11 | kuldiga
# Processing Record 17 of Set 11 | jinchengjiang
# Processing Record 18 of Set 11 | leningradskiy
# Processing Record 19 of Set 11 | lashio
# Processing Record 20 of Set 11 | kushiro
# Processing Record 21 of Set 11 | bar harbor
# Processing Record 22 of Set 11 | dzhusaly
# Processing Record 23 of Set 11 | micheweni
# Processing Record 24 of Set 11 | sorong
# Processing Record 25 of Set 11 | nuzvid
# Processing Record 26 of Set 11 | san jose
# Processing Record 27 of Set 11 | miraflores
# Processing Record 28 of Set 11 | bixby
# Processing Record 29 of Set 11 | clarence town
# Processing Record 30 of Set 11 | comodoro rivadavia
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | vestmannaeyjar
# Processing Record 33 of Set 11 | ancud
# Processing Record 34 of Set 11 | hirara
# Processing Record 35 of Set 11 | braintree
# Processing Record 36 of Set 11 | bowen
# Processing Record 37 of Set 11 | ostersund
# Processing Record 38 of Set 11 | solsvik
# Processing Record 39 of Set 11 | grindavik
# Processing Record 40 of Set 11 | abiy adi
# Processing Record 41 of Set 11 | montepuez
# Processing Record 42 of Set 11 | wichita falls
# Processing Record 43 of Set 11 | klaksvik
# Processing Record 44 of Set 11 | xai-xai
# Processing Record 45 of Set 11 | srandakan
# Processing Record 46 of Set 11 | candawaga
# Processing Record 47 of Set 11 | iturama
# Processing Record 48 of Set 11 | villa rica
# Processing Record 49 of Set 11 | ialibu
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | rapu-rapu
# Processing Record 2 of Set 12 | ferme-neuve
# Processing Record 3 of Set 12 | sinkat
# Processing Record 4 of Set 12 | wenling
# Processing Record 5 of Set 12 | cayenne
# Processing Record 6 of Set 12 | little current
# Processing Record 7 of Set 12 | alto vera
# Processing Record 8 of Set 12 | kitimat
# Processing Record 9 of Set 12 | cagayan de tawi-tawi
# Processing Record 10 of Set 12 | nokaneng
# Processing Record 11 of Set 12 | mitsamiouli
# Processing Record 12 of Set 12 | londiani
# Processing Record 13 of Set 12 | kalabo
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | dhupgari
# Processing Record 16 of Set 12 | faya
# Processing Record 17 of Set 12 | aketi
# Processing Record 18 of Set 12 | kuusamo
# Processing Record 19 of Set 12 | honiara
# Processing Record 20 of Set 12 | ahipara
# Processing Record 21 of Set 12 | mokshan
# Processing Record 22 of Set 12 | tateyama
# Processing Record 23 of Set 12 | indramayu
# Processing Record 24 of Set 12 | nisko
# Processing Record 25 of Set 12 | krumovgrad
# Processing Record 26 of Set 12 | aldan
# Processing Record 27 of Set 12 | ouegoa
# Processing Record 28 of Set 12 | nushki
# Processing Record 29 of Set 12 | visby
# Processing Record 30 of Set 12 | altamira
# Processing Record 31 of Set 12 | zhigansk
# Processing Record 32 of Set 12 | grand-santi
# Processing Record 33 of Set 12 | mattru
# Processing Record 34 of Set 12 | bokspits
# Processing Record 35 of Set 12 | atambua
# Processing Record 36 of Set 12 | sambava
# Processing Record 37 of Set 12 | ust-tsilma
# Processing Record 38 of Set 12 | sola
# Processing Record 39 of Set 12 | chapais
# Processing Record 40 of Set 12 | sao filipe
# Processing Record 41 of Set 12 | san carlos sija
# Processing Record 42 of Set 12 | walvis bay
# Processing Record 43 of Set 12 | ornskoldsvik
# Processing Record 44 of Set 12 | rochester
# Processing Record 45 of Set 12 | jalu
# Processing Record 46 of Set 12 | tekeli
# Processing Record 47 of Set 12 | naron
# Processing Record 48 of Set 12 | henties bay
# Processing Record 49 of Set 12 | rio grande
# Processing Record 50 of Set 12 | bud
# Processing Record 1 of Set 13 | morag
# Processing Record 2 of Set 13 | wloszczowa
# Processing Record 3 of Set 13 | vught
# Processing Record 4 of Set 13 | yerbogachen
# Processing Record 5 of Set 13 | manzhouli
# Processing Record 6 of Set 13 | nyurba
# Processing Record 7 of Set 13 | dibrugarh
# Processing Record 8 of Set 13 | sehithwa
# Processing Record 9 of Set 13 | cururupu
# Processing Record 10 of Set 13 | sturgis
# Processing Record 11 of Set 13 | san rafael
# Processing Record 12 of Set 13 | ondjiva
# Processing Record 13 of Set 13 | mococa
# Processing Record 14 of Set 13 | nanlong
# Processing Record 15 of Set 13 | suamico
# Processing Record 16 of Set 13 | asheville
# Processing Record 17 of Set 13 | fez
# Processing Record 18 of Set 13 | great falls
# Processing Record 19 of Set 13 | kalmunai
# Processing Record 20 of Set 13 | arlit
# Processing Record 21 of Set 13 | kruisfontein
# Processing Record 22 of Set 13 | bubaque
# Processing Record 23 of Set 13 | ardakan
# Processing Record 24 of Set 13 | pontianak
# Processing Record 25 of Set 13 | pinheiro machado
# Processing Record 26 of Set 13 | colombo
# Processing Record 27 of Set 13 | dera ghazi khan
# Processing Record 28 of Set 13 | fomboni
# Processing Record 29 of Set 13 | saint-georges
# Processing Record 30 of Set 13 | karasuk
# Processing Record 31 of Set 13 | booue
# Processing Record 32 of Set 13 | ust-nera
# Processing Record 33 of Set 13 | taseyevo
# Processing Record 34 of Set 13 | tome
# Processing Record 35 of Set 13 | jinchang
# Processing Record 36 of Set 13 | luancheng
# Processing Record 37 of Set 13 | araouane
# Processing Record 38 of Set 13 | mavrodin
# Processing Record 39 of Set 13 | zaros
# Processing Record 40 of Set 13 | barbar
# Processing Record 41 of Set 13 | banepa
# Processing Record 42 of Set 13 | coulihaut
# Processing Record 43 of Set 13 | camacari
# Processing Record 44 of Set 13 | formosa
# Processing Record 45 of Set 13 | birao
# Processing Record 46 of Set 13 | pangnirtung
# Processing Record 47 of Set 13 | raudeberg
# Processing Record 48 of Set 13 | west plains
# Processing Record 49 of Set 13 | labrea
# Processing Record 50 of Set 13 | guaratinga
# Processing Record 1 of Set 14 | york
# Processing Record 2 of Set 14 | villanueva de la serena
# Processing Record 3 of Set 14 | naftah
# Processing Record 4 of Set 14 | lunglei
# Processing Record 5 of Set 14 | bongandanga
# Processing Record 6 of Set 14 | chifeng
# Processing Record 7 of Set 14 | junin
# Processing Record 8 of Set 14 | kolondieba
# Processing Record 9 of Set 14 | ahuimanu
# Processing Record 10 of Set 14 | kambove
# Processing Record 11 of Set 14 | tazovskiy
# Processing Record 12 of Set 14 | port hardy
# Processing Record 13 of Set 14 | moerai
# Processing Record 14 of Set 14 | valera
# Processing Record 15 of Set 14 | irati
# Processing Record 16 of Set 14 | lufilufi
# Processing Record 17 of Set 14 | novyye lyady
# Processing Record 18 of Set 14 | quatre cocos
# Processing Record 19 of Set 14 | bereda
# Processing Record 20 of Set 14 | breisach
# Processing Record 21 of Set 14 | longyearbyen
# Processing Record 22 of Set 14 | along
# Processing Record 23 of Set 14 | aldergrove
# Processing Record 24 of Set 14 | priargunsk
# Processing Record 25 of Set 14 | byron bay
# Processing Record 26 of Set 14 | bunia
# Processing Record 27 of Set 14 | pingliang
# Processing Record 28 of Set 14 | ekhabi
# Processing Record 29 of Set 14 | neepawa
# Processing Record 30 of Set 14 | batemans bay
# Processing Record 31 of Set 14 | longlac
# Processing Record 32 of Set 14 | altay
# Processing Record 33 of Set 14 | kemlya
# Processing Record 34 of Set 14 | emerald
# Processing Record 35 of Set 14 | coahuayana
# Processing Record 36 of Set 14 | pueblo nuevo solistahuacan
# Processing Record 37 of Set 14 | flin flon
# Processing Record 38 of Set 14 | carauari
# Processing Record 39 of Set 14 | coihaique
# Processing Record 40 of Set 14 | melaka
# Processing Record 41 of Set 14 | harper
# Processing Record 42 of Set 14 | cairns
# Processing Record 43 of Set 14 | dakar
# Processing Record 44 of Set 14 | satkhira
# Processing Record 45 of Set 14 | villa vazquez
# Processing Record 46 of Set 14 | nevers
# Processing Record 47 of Set 14 | rudnogorsk
# Processing Record 48 of Set 14 | honningsvag
# Processing Record 49 of Set 14 | srednekolymsk
# Processing Record 50 of Set 14 | eregli
# Processing Record 1 of Set 15 | chaman
# Processing Record 2 of Set 15 | hami
# Processing Record 3 of Set 15 | juegang
# Processing Record 4 of Set 15 | yendi
# Processing Record 5 of Set 15 | aquiraz
# Processing Record 6 of Set 15 | thunder bay
# Processing Record 7 of Set 15 | san francisco menendez
# Processing Record 8 of Set 15 | arman
# Processing Record 9 of Set 15 | hohhot
# Processing Record 10 of Set 15 | vostok
# Processing Record 11 of Set 15 | bocaranga
# Processing Record 12 of Set 15 | indianola
# Processing Record 13 of Set 15 | edson
# Processing Record 14 of Set 15 | yumen
# Processing Record 15 of Set 15 | kichera
# Processing Record 16 of Set 15 | ikeda
# Processing Record 17 of Set 15 | brandon
# Processing Record 18 of Set 15 | rocha
# Processing Record 19 of Set 15 | chokwe
# Processing Record 20 of Set 15 | zeulenroda
# Processing Record 21 of Set 15 | balasinor
# Processing Record 22 of Set 15 | santa barbara
# Processing Record 23 of Set 15 | ketrzyn
# Processing Record 24 of Set 15 | amboise
# Processing Record 25 of Set 15 | bandarbeyla
# Processing Record 26 of Set 15 | turukhansk
# Processing Record 27 of Set 15 | kanevskaya
# Processing Record 28 of Set 15 | mecca
# Processing Record 29 of Set 15 | mata
# Processing Record 30 of Set 15 | borkenes
# Processing Record 31 of Set 15 | malpura
# Processing Record 32 of Set 15 | kafanchan
# Processing Record 33 of Set 15 | ilebo
# Processing Record 34 of Set 15 | kangaba
# Processing Record 35 of Set 15 | gigmoto
# Processing Record 36 of Set 15 | mehamn
# Processing Record 37 of Set 15 | kingston
# Processing Record 38 of Set 15 | chunskiy
# Processing Record 39 of Set 15 | do rud
# Processing Record 40 of Set 15 | taunggyi
# Processing Record 41 of Set 15 | guilin
# Processing Record 42 of Set 15 | goias
# Processing Record 43 of Set 15 | alappuzha
# Processing Record 44 of Set 15 | bull savanna
# Processing Record 45 of Set 15 | kamiiso
# Processing Record 46 of Set 15 | saravan
# Processing Record 47 of Set 15 | lazaro cardenas
# Processing Record 48 of Set 15 | nizhneyansk
# Processing Record 49 of Set 15 | sai buri
# Processing Record 50 of Set 15 | douglas
# Processing Record 1 of Set 16 | tahe
# Processing Record 2 of Set 16 | naerbo
# Processing Record 3 of Set 16 | preveza
# Processing Record 4 of Set 16 | chara
# Processing Record 5 of Set 16 | boulder city
# Processing Record 6 of Set 16 | nata
# Processing Record 7 of Set 16 | eilenburg
# Processing Record 8 of Set 16 | la ronge
# Processing Record 9 of Set 16 | nishihara
# Processing Record 10 of Set 16 | farafenni
# Processing Record 11 of Set 16 | jardim
# Processing Record 12 of Set 16 | male
# Processing Record 13 of Set 16 | sataua
# Processing Record 14 of Set 16 | alakurtti
# Processing Record 15 of Set 16 | goroka
# Processing Record 16 of Set 16 | boende
# Processing Record 17 of Set 16 | mykhaylivka
# Processing Record 18 of Set 16 | yangliuqing
# Processing Record 19 of Set 16 | havelock
# Processing Record 20 of Set 16 | makat
# Processing Record 21 of Set 16 | tumaco
# Processing Record 22 of Set 16 | kawardha
# Processing Record 23 of Set 16 | bekhtery
# Processing Record 24 of Set 16 | gonbad-e qabus
# Processing Record 25 of Set 16 | hokitika
# Processing Record 26 of Set 16 | teguise
# Processing Record 27 of Set 16 | lar
# Processing Record 28 of Set 16 | warri
# Processing Record 29 of Set 16 | shakhtinsk
# Processing Record 30 of Set 16 | rio gallegos
# Processing Record 31 of Set 16 | kortkeros
# Processing Record 32 of Set 16 | ouallam
# Processing Record 33 of Set 16 | aripuana
# Processing Record 34 of Set 16 | negombo
# Processing Record 35 of Set 16 | voi
# Processing Record 36 of Set 16 | carndonagh
# Processing Record 37 of Set 16 | oistins
# Processing Record 38 of Set 16 | yeppoon
# Processing Record 39 of Set 16 | tungor
# Processing Record 40 of Set 16 | bayan
# Processing Record 41 of Set 16 | ngorongoro
# Processing Record 42 of Set 16 | mashhad
# Processing Record 43 of Set 16 | moyo
# Processing Record 44 of Set 16 | bagdarin
# Processing Record 45 of Set 16 | turayf
# Processing Record 46 of Set 16 | rocky mountain house
# Processing Record 47 of Set 16 | la palma
# Processing Record 48 of Set 16 | watsa
# Processing Record 49 of Set 16 | sao jose da coroa grande
# Processing Record 50 of Set 16 | albany
# Processing Record 51 of Set 16 | ushuaia
# Processing Record 52 of Set 16 | rikitea
# Processing Record 53 of Set 16 | salamiyah
# Processing Record 54 of Set 16 | mahebourg
# Processing Record 55 of Set 16 | vitoria
# Processing Record 56 of Set 16 | sidi ali
# Processing Record 57 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 58 of Set 16 | panacan
# Processing Record 59 of Set 16 | pasir gudang
# Processing Record 60 of Set 16 | galle
# Processing Record 61 of Set 16 | marawi
# Processing Record 62 of Set 16 | salamanca
# Processing Record 63 of Set 16 | atherton
# Processing Record 64 of Set 16 | victoria
# Processing Record 65 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 66 of Set 16 | isangel
# Processing Record 67 of Set 16 | teacapan
# Processing Record 68 of Set 16 | tbilisskaya
# Processing Record 69 of Set 16 | ambilobe
# Processing Record 70 of Set 16 | mahanoro
# Processing Record 71 of Set 16 | gra liyia
# Processing Record 72 of Set 16 | hit
# Processing Record 73 of Set 16 | letlhakane
# Processing Record 74 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 75 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 76 of Set 16 | limbang
# Processing Record 77 of Set 16 | puerto ayora
# Processing Record 78 of Set 16 | hithadhoo
# Processing Record 79 of Set 16 | hasaki
# Processing Record 80 of Set 16 | kudahuvadhoo
# Processing Record 81 of Set 16 | florence
# Processing Record 82 of Set 16 | khatanga
# Processing Record 83 of Set 16 | puerto escondido
# Processing Record 84 of Set 16 | boyabat
# Processing Record 85 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 86 of Set 16 | hilo
# Processing Record 87 of Set 16 | vaini
# Processing Record 88 of Set 16 | northam
# Processing Record 89 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 90 of Set 16 | miracatu
# Processing Record 91 of Set 16 | lebu
# Processing Record 92 of Set 16 | ilulissat
# Processing Record 93 of Set 16 | chulman
# Processing Record 94 of Set 16 | arraial do cabo
# Processing Record 95 of Set 16 | ribeira grande
# Processing Record 96 of Set 16 | mataura
# Processing Record 97 of Set 16 | east london
# Processing Record 98 of Set 16 | castro
# Processing Record 99 of Set 16 | upernavik
# Processing Record 1 of Set 17 | saskylakh
# Processing Record 2 of Set 17 | katsuura
# Processing Record 3 of Set 17 | saldanha
# Processing Record 4 of Set 17 | villamontes
# Processing Record 5 of Set 17 | jamnagar
# Processing Record 6 of Set 17 | luderitz
# Processing Record 7 of Set 17 | kurilsk
# Processing Record 8 of Set 17 | new norfolk
# Processing Record 9 of Set 17 | thinadhoo
# Processing Record 10 of Set 17 | alofi
# Processing Record 11 of Set 17 | prado
# Processing Record 12 of Set 17 | qaanaaq
# Processing Record 13 of Set 17 | barcelos
# Processing Record 14 of Set 17 | galesong
# Processing Record 15 of Set 17 | carnarvon
# Processing Record 16 of Set 17 | kodiak
# Processing Record 17 of Set 17 | kapaa
# Processing Record 18 of Set 17 | launceston
# Processing Record 19 of Set 17 | francistown
# Processing Record 20 of Set 17 | sainte-maxime
# Processing Record 21 of Set 17 | stoyba
# City not found. Skipping...
# Processing Record 22 of Set 17 | jaca
# Processing Record 23 of Set 17 | avarua
# Processing Record 24 of Set 17 | punta arenas
# Processing Record 25 of Set 17 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 17 | bambous virieux
# Processing Record 27 of Set 17 | tamale
# Processing Record 28 of Set 17 | nelson bay
# Processing Record 29 of Set 17 | tuktoyaktuk
# Processing Record 30 of Set 17 | petrozavodsk
# Processing Record 31 of Set 17 | atuona
# Processing Record 32 of Set 17 | chavakkad
# Processing Record 33 of Set 17 | nanortalik
# Processing Record 34 of Set 17 | busselton
# Processing Record 35 of Set 17 | sitka
# Processing Record 36 of Set 17 | umea
# Processing Record 37 of Set 17 | port lincoln
# Processing Record 38 of Set 17 | souillac
# Processing Record 39 of Set 17 | guerrero negro
# Processing Record 40 of Set 17 | dikson
# Processing Record 41 of Set 17 | barrow
# Processing Record 42 of Set 17 | butaritari
# Processing Record 43 of Set 17 | manokwari
# Processing Record 44 of Set 17 | machiques
# Processing Record 45 of Set 17 | shingu
# Processing Record 46 of Set 17 | sungaipenuh
# Processing Record 47 of Set 17 | taree
# Processing Record 48 of Set 17 | hermanus
# Processing Record 49 of Set 17 | phalaborwa
# Processing Record 50 of Set 17 | dunedin
# Processing Record 1 of Set 18 | amapa
# Processing Record 2 of Set 18 | baykit
# Processing Record 3 of Set 18 | talnakh
# Processing Record 4 of Set 18 | santa maria
# Processing Record 5 of Set 18 | port elizabeth
# Processing Record 6 of Set 18 | tazmalt
# Processing Record 7 of Set 18 | jamestown
# Processing Record 8 of Set 18 | bethel
# Processing Record 9 of Set 18 | vila franca do campo
# Processing Record 10 of Set 18 | astoria
# Processing Record 11 of Set 18 | mar del plata
# Processing Record 12 of Set 18 | aklavik
# Processing Record 13 of Set 18 | hovd
# Processing Record 14 of Set 18 | esfahan
# Processing Record 15 of Set 18 | tutoia
# Processing Record 16 of Set 18 | touros
# Processing Record 17 of Set 18 | constitucion
# Processing Record 18 of Set 18 | namibe
# Processing Record 19 of Set 18 | severo-kurilsk
# Processing Record 20 of Set 18 | bathsheba
# Processing Record 21 of Set 18 | cape town
# Processing Record 22 of Set 18 | hobart
# Processing Record 23 of Set 18 | vila velha
# Processing Record 24 of Set 18 | chokurdakh
# Processing Record 25 of Set 18 | stodolishche
# Processing Record 26 of Set 18 | djambala
# Processing Record 27 of Set 18 | bereznik
# Processing Record 28 of Set 18 | kurchum
# Processing Record 29 of Set 18 | ponta delgada
# Processing Record 30 of Set 18 | nikolskoye
# Processing Record 31 of Set 18 | dingle
# Processing Record 32 of Set 18 | camacha
# Processing Record 33 of Set 18 | brigantine
# Processing Record 34 of Set 18 | lorengau
# Processing Record 35 of Set 18 | swellendam
# Processing Record 36 of Set 18 | puerto maldonado
# Processing Record 37 of Set 18 | kununurra
# Processing Record 38 of Set 18 | broome
# Processing Record 39 of Set 18 | buraydah
# Processing Record 40 of Set 18 | gat
# Processing Record 41 of Set 18 | chuy
# Processing Record 42 of Set 18 | saint-joseph
# Processing Record 43 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 18 | nenjiang
# Processing Record 45 of Set 18 | opuwo
# Processing Record 46 of Set 18 | veraval
# Processing Record 47 of Set 18 | hualmay
# Processing Record 48 of Set 18 | kathu
# Processing Record 49 of Set 18 | sulphur
# Processing Record 50 of Set 18 | breznik
# Processing Record 1 of Set 19 | jenison
# Processing Record 2 of Set 19 | lasa
# Processing Record 3 of Set 19 | rexburg
# Processing Record 4 of Set 19 | iqaluit
# Processing Record 5 of Set 19 | port alfred
# Processing Record 6 of Set 19 | cherskiy
# Processing Record 7 of Set 19 | thompson
# Processing Record 8 of Set 19 | faanui
# Processing Record 9 of Set 19 | yellowknife
# Processing Record 10 of Set 19 | kalaleh
# Processing Record 11 of Set 19 | georgetown
# Processing Record 12 of Set 19 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 19 | palauig
# Processing Record 14 of Set 19 | samarai
# Processing Record 15 of Set 19 | tautira
# Processing Record 16 of Set 19 | bluff
# Processing Record 17 of Set 19 | autazes
# Processing Record 18 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 19 | riyadh
# Processing Record 20 of Set 19 | kozhva
# Processing Record 21 of Set 19 | aragarcas
# Processing Record 22 of Set 19 | dauriya
# Processing Record 23 of Set 19 | buenavista
# Processing Record 24 of Set 19 | saint george
# Processing Record 25 of Set 19 | alta
# Processing Record 26 of Set 19 | key largo
# Processing Record 27 of Set 19 | lata
# Processing Record 28 of Set 19 | mayo
# Processing Record 29 of Set 19 | riese
# City not found. Skipping...
# Processing Record 30 of Set 19 | najran
# Processing Record 31 of Set 19 | antsohihy
# Processing Record 32 of Set 19 | necochea
# Processing Record 33 of Set 19 | hamilton
# Processing Record 34 of Set 19 | hong gai
# Processing Record 35 of Set 19 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 19 | kiama
# Processing Record 37 of Set 19 | antalaha
# Processing Record 38 of Set 19 | yulara
# Processing Record 39 of Set 19 | kailua
# Processing Record 40 of Set 19 | bredasdorp
# Processing Record 41 of Set 19 | portsoy
# Processing Record 42 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 19 | sovetskiy
# Processing Record 44 of Set 19 | novyy urgal
# Processing Record 45 of Set 19 | vuktyl
# Processing Record 46 of Set 19 | portland
# Processing Record 47 of Set 19 | surgut
# Processing Record 48 of Set 19 | lagoa
# Processing Record 49 of Set 19 | lexington
# Processing Record 50 of Set 19 | codrington
# Processing Record 1 of Set 20 | mwene-ditu
# Processing Record 2 of Set 20 | homer
# Processing Record 3 of Set 20 | aykhal
# Processing Record 4 of Set 20 | batagay
# Processing Record 5 of Set 20 | belmonte
# Processing Record 6 of Set 20 | panaba
# Processing Record 7 of Set 20 | puerto gaitan
# Processing Record 8 of Set 20 | wajima
# Processing Record 9 of Set 20 | tasiilaq
# Processing Record 10 of Set 20 | flinders
# Processing Record 11 of Set 20 | vanimo
# Processing Record 12 of Set 20 | pisco
# Processing Record 13 of Set 20 | salinas
# Processing Record 14 of Set 20 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 20 | sept-iles
# Processing Record 16 of Set 20 | zyryanka
# Processing Record 17 of Set 20 | barranca
# Processing Record 18 of Set 20 | caronport
# Processing Record 19 of Set 20 | charters towers
# Processing Record 20 of Set 20 | clyde river
# Processing Record 21 of Set 20 | katangli
# Processing Record 22 of Set 20 | airai
# Processing Record 23 of Set 20 | penzance
# Processing Record 24 of Set 20 | nawabganj
# Processing Record 25 of Set 20 | iquique
# Processing Record 26 of Set 20 | noumea
# Processing Record 27 of Set 20 | tiszasuly
# Processing Record 28 of Set 20 | krasnoarmeysk
# Processing Record 29 of Set 20 | komsomolskiy
# Processing Record 30 of Set 20 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 31 of Set 20 | saint-philippe
# Processing Record 32 of Set 20 | medicine hat
# Processing Record 33 of Set 20 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 20 | muroto
# Processing Record 35 of Set 20 | vao
# Processing Record 36 of Set 20 | portobelo
# Processing Record 37 of Set 20 | itarema
# Processing Record 38 of Set 20 | avera
# Processing Record 39 of Set 20 | paamiut
# Processing Record 40 of Set 20 | san cristobal
# Processing Record 41 of Set 20 | oussouye
# Processing Record 42 of Set 20 | tanshui
# City not found. Skipping...
# Processing Record 43 of Set 20 | qaqortoq
# Processing Record 44 of Set 20 | fortuna
# Processing Record 45 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 20 | batagay-alyta
# Processing Record 47 of Set 20 | bambanglipuro
# Processing Record 48 of Set 20 | ponta do sol
# Processing Record 49 of Set 20 | takaka
# Processing Record 50 of Set 20 | saint-augustin
# Processing Record 1 of Set 21 | mount gambier
# Processing Record 2 of Set 21 | ola
# Processing Record 3 of Set 21 | humboldt
# Processing Record 4 of Set 21 | makakilo city
# Processing Record 5 of Set 21 | pevek
# Processing Record 6 of Set 21 | fasa
# Processing Record 7 of Set 21 | shenjiamen
# Processing Record 8 of Set 21 | francheville
# Processing Record 9 of Set 21 | getulio vargas
# Processing Record 10 of Set 21 | kavieng
# Processing Record 11 of Set 21 | lerwick
# Processing Record 12 of Set 21 | mende
# Processing Record 13 of Set 21 | narrabri
# Processing Record 14 of Set 21 | nacozari
# Processing Record 15 of Set 21 | kloulklubed
# Processing Record 16 of Set 21 | fairbanks
# Processing Record 17 of Set 21 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 21 | salalah
# Processing Record 19 of Set 21 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 21 | sakakah
# Processing Record 21 of Set 21 | shubarshi
# Processing Record 22 of Set 21 | tessalit
# Processing Record 23 of Set 21 | tuatapere
# Processing Record 24 of Set 21 | burgeo
# Processing Record 25 of Set 21 | narsaq
# Processing Record 26 of Set 21 | celestun
# Processing Record 27 of Set 21 | sarangani
# Processing Record 28 of Set 21 | bom jesus da lapa
# Processing Record 29 of Set 21 | pedasi
# Processing Record 30 of Set 21 | porto novo
# Processing Record 31 of Set 21 | sabha
# Processing Record 32 of Set 21 | jackson
# Processing Record 33 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 21 | coquimbo
# Processing Record 35 of Set 21 | alma
# Processing Record 36 of Set 21 | tongliao
# Processing Record 37 of Set 21 | krasnyy oktyabr
# Processing Record 38 of Set 21 | dudinka
# Processing Record 39 of Set 21 | hammerfest
# Processing Record 40 of Set 21 | iskateley
# Processing Record 41 of Set 21 | soe
# Processing Record 42 of Set 21 | collie
# Processing Record 43 of Set 21 | muzhi
# Processing Record 44 of Set 21 | wuzhou
# Processing Record 45 of Set 21 | kaka
# Processing Record 46 of Set 21 | jaciara
# Processing Record 47 of Set 21 | waipawa
# Processing Record 48 of Set 21 | bodden town
# Processing Record 49 of Set 21 | kavaratti
# Processing Record 50 of Set 21 | peleduy
# Processing Record 1 of Set 22 | alexandria
# Processing Record 2 of Set 22 | geraldton
# Processing Record 3 of Set 22 | eureka
# Processing Record 4 of Set 22 | santa luzia
# Processing Record 5 of Set 22 | lakhipur
# Processing Record 6 of Set 22 | diffa
# Processing Record 7 of Set 22 | port macquarie
# Processing Record 8 of Set 22 | kamenka
# Processing Record 9 of Set 22 | inuvik
# Processing Record 10 of Set 22 | fort nelson
# Processing Record 11 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 22 | svetlyy
# Processing Record 13 of Set 22 | lompoc
# Processing Record 14 of Set 22 | auki
# Processing Record 15 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 22 | udachnyy
# Processing Record 17 of Set 22 | wamba
# Processing Record 18 of Set 22 | sistranda
# Processing Record 19 of Set 22 | kidal
# Processing Record 20 of Set 22 | le port
# Processing Record 21 of Set 22 | eyl
# Processing Record 22 of Set 22 | bengkulu
# Processing Record 23 of Set 22 | magadan
# Processing Record 24 of Set 22 | marmashen
# Processing Record 25 of Set 22 | marathon
# Processing Record 26 of Set 22 | andenes
# Processing Record 27 of Set 22 | tura
# Processing Record 28 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 22 | torbay
# Processing Record 30 of Set 22 | termoli
# Processing Record 31 of Set 22 | san vicente
# Processing Record 32 of Set 22 | surab
# Processing Record 33 of Set 22 | santa lucia
# ...
# Processing Record 42 of Set 24 | puerto carreno
# Processing Record 43 of Set 24 | teya
# Processing Record 44 of Set 24 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 24 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 24 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 24 | calvinia
# Processing Record 48 of Set 24 | kaeo
# Processing Record 49 of Set 24 | fenyi
# Processing Record 50 of Set 24 | prince rupert
# Processing Record 1 of Set 25 | santa rosa
# Processing Record 2 of Set 25 | gisborne
# Processing Record 3 of Set 25 | markivka
# Processing Record 4 of Set 25 | guantanamo
# Processing Record 5 of Set 25 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 25 | provideniya
# Processing Record 7 of Set 25 | kiunga
# Processing Record 8 of Set 25 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 25 | camuy
# Processing Record 10 of Set 25 | darhan
# Processing Record 11 of Set 25 | inta
# Processing Record 12 of Set 25 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 25 | sahrak
# City not found. Skipping...
# Processing Record 14 of Set 25 | north myrtle beach
# Processing Record 15 of Set 25 | kaga
# Processing Record 16 of Set 25 | laiwu
# Processing Record 17 of Set 25 | kieta
# Processing Record 18 of Set 25 | oranjemund
# Processing Record 19 of Set 25 | meulaboh
# Processing Record 20 of Set 25 | xining
# Processing Record 21 of Set 25 | westport
# Processing Record 22 of Set 25 | ust-barguzin
# Processing Record 23 of Set 25 | pastavy
# Processing Record 24 of Set 25 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 25 | weyburn
# Processing Record 26 of Set 25 | nouadhibou
# Processing Record 27 of Set 25 | jining
# Processing Record 28 of Set 25 | wad rawah
# Processing Record 29 of Set 25 | carlagan
# Processing Record 30 of Set 25 | kushmurun
# Processing Record 31 of Set 25 | fort saint james
# Processing Record 32 of Set 25 | yakeshi
# Processing Record 33 of Set 25 | omboue
# Processing Record 34 of Set 25 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 25 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 25 | college
# Processing Record 37 of Set 25 | jabiru
# City not found. Skipping...
# Processing Record 38 of Set 25 | pochutla
# Processing Record 39 of Set 25 | jhelum
# Processing Record 40 of Set 25 | ankazoabo
# Processing Record 41 of Set 25 | sorland
# Processing Record 42 of Set 25 | mersing
# Processing Record 43 of Set 25 | bhadravati
# Processing Record 44 of Set 25 | mahon
# Processing Record 45 of Set 25 | ushumun
# Processing Record 46 of Set 25 | chicama
# Processing Record 47 of Set 25 | crixas
# Processing Record 48 of Set 25 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 25 | nalut
# Processing Record 50 of Set 25 | voh
# Processing Record 1 of Set 26 | yar-sale
# Processing Record 2 of Set 26 | port augusta
# Processing Record 3 of Set 26 | tukrah
# Processing Record 4 of Set 26 | olinda
# Processing Record 5 of Set 26 | alice springs
# Processing Record 6 of Set 26 | sur
# Processing Record 7 of Set 26 | albemarle
# Processing Record 8 of Set 26 | mahaicony
# City not found. Skipping...
# Processing Record 9 of Set 26 | myitkyina
# Processing Record 10 of Set 26 | inhambane
# Processing Record 11 of Set 26 | maniitsoq
# Processing Record 12 of Set 26 | sharjah
# Processing Record 13 of Set 26 | hobyo
# Processing Record 14 of Set 26 | seoul
# Processing Record 15 of Set 26 | tafo
# Processing Record 16 of Set 26 | kuldiga
# Processing Record 17 of Set 26 | jinchengjiang
# City not found. Skipping...
# Processing Record 18 of Set 26 | leningradskiy
# Processing Record 19 of Set 26 | lashio
# Processing Record 20 of Set 26 | kushiro
# Processing Record 21 of Set 26 | bar harbor
# Processing Record 22 of Set 26 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 26 | micheweni
# Processing Record 24 of Set 26 | sorong
# Processing Record 25 of Set 26 | nuzvid
# Processing Record 26 of Set 26 | san jose
# Processing Record 27 of Set 26 | miraflores
# Processing Record 28 of Set 26 | bixby
# Processing Record 29 of Set 26 | clarence town
# Processing Record 30 of Set 26 | comodoro rivadavia
# Processing Record 31 of Set 26 | te anau
# Processing Record 32 of Set 26 | vestmannaeyjar
# Processing Record 33 of Set 26 | ancud
# Processing Record 34 of Set 26 | hirara
# Processing Record 35 of Set 26 | braintree
# Processing Record 36 of Set 26 | bowen
# Processing Record 37 of Set 26 | ostersund
# Processing Record 38 of Set 26 | solsvik
# City not found. Skipping...
# Processing Record 39 of Set 26 | grindavik
# Processing Record 40 of Set 26 | abiy adi
# City not found. Skipping...
# Processing Record 41 of Set 26 | montepuez
# Processing Record 42 of Set 26 | wichita falls
# Processing Record 43 of Set 26 | klaksvik
# Processing Record 44 of Set 26 | xai-xai
# Processing Record 45 of Set 26 | srandakan
# Processing Record 46 of Set 26 | candawaga
# City not found. Skipping...
# Processing Record 47 of Set 26 | iturama
# Processing Record 48 of Set 26 | villa rica
# Processing Record 49 of Set 26 | ialibu
# Processing Record 50 of Set 26 | hofn
# Processing Record 1 of Set 27 | rapu-rapu
# Processing Record 2 of Set 27 | ferme-neuve
# Processing Record 3 of Set 27 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 27 | wenling
# Processing Record 5 of Set 27 | cayenne
# Processing Record 6 of Set 27 | little current
# Processing Record 7 of Set 27 | alto vera
# City not found. Skipping...
# Processing Record 8 of Set 27 | kitimat
# Processing Record 9 of Set 27 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 10 of Set 27 | nokaneng
# Processing Record 11 of Set 27 | mitsamiouli
# Processing Record 12 of Set 27 | londiani
# Processing Record 13 of Set 27 | kalabo
# Processing Record 14 of Set 27 | olafsvik
# Processing Record 15 of Set 27 | dhupgari
# Processing Record 16 of Set 27 | faya
# Processing Record 17 of Set 27 | aketi
# Processing Record 18 of Set 27 | kuusamo
# Processing Record 19 of Set 27 | honiara
# Processing Record 20 of Set 27 | ahipara
# Processing Record 21 of Set 27 | mokshan
# Processing Record 22 of Set 27 | tateyama
# Processing Record 23 of Set 27 | indramayu
# Processing Record 24 of Set 27 | nisko
# Processing Record 25 of Set 27 | krumovgrad
# Processing Record 26 of Set 27 | aldan
# Processing Record 27 of Set 27 | ouegoa
# Processing Record 28 of Set 27 | nushki
# Processing Record 29 of Set 27 | visby
# Processing Record 30 of Set 27 | altamira
# Processing Record 31 of Set 27 | zhigansk
# Processing Record 32 of Set 27 | grand-santi
# Processing Record 33 of Set 27 | mattru
# Processing Record 34 of Set 27 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 27 | atambua
# Processing Record 36 of Set 27 | sambava
# Processing Record 37 of Set 27 | ust-tsilma
# Processing Record 38 of Set 27 | sola
# Processing Record 39 of Set 27 | chapais
# Processing Record 40 of Set 27 | sao filipe
# Processing Record 41 of Set 27 | san carlos sija
# Processing Record 42 of Set 27 | walvis bay
# Processing Record 43 of Set 27 | ornskoldsvik
# Processing Record 44 of Set 27 | rochester
# Processing Record 45 of Set 27 | jalu
# Processing Record 46 of Set 27 | tekeli
# Processing Record 47 of Set 27 | naron
# Processing Record 48 of Set 27 | henties bay
# Processing Record 49 of Set 27 | rio grande
# Processing Record 50 of Set 27 | bud
# Processing Record 1 of Set 28 | morag
# Processing Record 2 of Set 28 | wloszczowa
# Processing Record 3 of Set 28 | vught
# Processing Record 4 of Set 28 | yerbogachen
# Processing Record 5 of Set 28 | manzhouli
# Processing Record 6 of Set 28 | nyurba
# Processing Record 7 of Set 28 | dibrugarh
# Processing Record 8 of Set 28 | sehithwa
# Processing Record 9 of Set 28 | cururupu
# Processing Record 10 of Set 28 | sturgis
# Processing Record 11 of Set 28 | san rafael
# Processing Record 12 of Set 28 | ondjiva
# Processing Record 13 of Set 28 | mococa
# Processing Record 14 of Set 28 | nanlong
# Processing Record 15 of Set 28 | suamico
# Processing Record 16 of Set 28 | asheville
# Processing Record 17 of Set 28 | fez
# Processing Record 18 of Set 28 | great falls
# Processing Record 19 of Set 28 | kalmunai
# Processing Record 20 of Set 28 | arlit
# Processing Record 21 of Set 28 | kruisfontein
# Processing Record 22 of Set 28 | bubaque
# Processing Record 23 of Set 28 | ardakan
# Processing Record 24 of Set 28 | pontianak
# Processing Record 25 of Set 28 | pinheiro machado
# Processing Record 26 of Set 28 | colombo
# Processing Record 27 of Set 28 | dera ghazi khan
# Processing Record 28 of Set 28 | fomboni
# Processing Record 29 of Set 28 | saint-georges
# Processing Record 30 of Set 28 | karasuk
# Processing Record 31 of Set 28 | booue
# Processing Record 32 of Set 28 | ust-nera
# Processing Record 33 of Set 28 | taseyevo
# Processing Record 34 of Set 28 | tome
# Processing Record 35 of Set 28 | jinchang
# Processing Record 36 of Set 28 | luancheng
# Processing Record 37 of Set 28 | araouane
# Processing Record 38 of Set 28 | mavrodin
# Processing Record 39 of Set 28 | zaros
# Processing Record 40 of Set 28 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 28 | banepa
# Processing Record 42 of Set 28 | coulihaut
# City not found. Skipping...
# Processing Record 43 of Set 28 | camacari
# Processing Record 44 of Set 28 | formosa
# Processing Record 45 of Set 28 | birao
# Processing Record 46 of Set 28 | pangnirtung
# Processing Record 47 of Set 28 | raudeberg
# Processing Record 48 of Set 28 | west plains
# Processing Record 49 of Set 28 | labrea
# Processing Record 50 of Set 28 | guaratinga
# Processing Record 1 of Set 29 | york
# Processing Record 2 of Set 29 | villanueva de la serena
# Processing Record 3 of Set 29 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 29 | lunglei
# Processing Record 5 of Set 29 | bongandanga
# Processing Record 6 of Set 29 | chifeng
# Processing Record 7 of Set 29 | junin
# Processing Record 8 of Set 29 | kolondieba
# Processing Record 9 of Set 29 | ahuimanu
# Processing Record 10 of Set 29 | kambove
# Processing Record 11 of Set 29 | tazovskiy
# Processing Record 12 of Set 29 | port hardy
# Processing Record 13 of Set 29 | moerai
# Processing Record 14 of Set 29 | valera
# Processing Record 15 of Set 29 | irati
# Processing Record 16 of Set 29 | lufilufi
# Processing Record 17 of Set 29 | novyye lyady
# Processing Record 18 of Set 29 | quatre cocos
# Processing Record 19 of Set 29 | bereda
# Processing Record 20 of Set 29 | breisach
# Processing Record 21 of Set 29 | longyearbyen
# Processing Record 22 of Set 29 | along
# Processing Record 23 of Set 29 | aldergrove
# Processing Record 24 of Set 29 | priargunsk
# Processing Record 25 of Set 29 | byron bay
# Processing Record 26 of Set 29 | bunia
# Processing Record 27 of Set 29 | pingliang
# Processing Record 28 of Set 29 | ekhabi
# Processing Record 29 of Set 29 | neepawa
# Processing Record 30 of Set 29 | batemans bay
# Processing Record 31 of Set 29 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 29 | altay
# Processing Record 33 of Set 29 | kemlya
# Processing Record 34 of Set 29 | emerald
# Processing Record 35 of Set 29 | coahuayana
# Processing Record 36 of Set 29 | pueblo nuevo solistahuacan
# Processing Record 37 of Set 29 | flin flon
# Processing Record 38 of Set 29 | carauari
# Processing Record 39 of Set 29 | coihaique
# Processing Record 40 of Set 29 | melaka
# Processing Record 41 of Set 29 | harper
# Processing Record 42 of Set 29 | cairns
# Processing Record 43 of Set 29 | dakar
# Processing Record 44 of Set 29 | satkhira
# Processing Record 45 of Set 29 | villa vazquez
# City not found. Skipping...
# Processing Record 46 of Set 29 | nevers
# Processing Record 47 of Set 29 | rudnogorsk
# Processing Record 48 of Set 29 | honningsvag
# Processing Record 49 of Set 29 | srednekolymsk
# Processing Record 50 of Set 29 | eregli
# Processing Record 1 of Set 30 | chaman
# Processing Record 2 of Set 30 | hami
# Processing Record 3 of Set 30 | juegang
# Processing Record 4 of Set 30 | yendi
# Processing Record 5 of Set 30 | aquiraz
# Processing Record 6 of Set 30 | thunder bay
# Processing Record 7 of Set 30 | san francisco menendez
# Processing Record 8 of Set 30 | arman
# Processing Record 9 of Set 30 | hohhot
# Processing Record 10 of Set 30 | vostok
# Processing Record 11 of Set 30 | bocaranga
# City not found. Skipping...
# Processing Record 12 of Set 30 | indianola
# Processing Record 13 of Set 30 | edson
# Processing Record 14 of Set 30 | yumen
# Processing Record 15 of Set 30 | kichera
# Processing Record 16 of Set 30 | ikeda
# Processing Record 17 of Set 30 | brandon
# Processing Record 18 of Set 30 | rocha
# Processing Record 19 of Set 30 | chokwe
# Processing Record 20 of Set 30 | zeulenroda
# Processing Record 21 of Set 30 | balasinor
# City not found. Skipping...
# Processing Record 22 of Set 30 | santa barbara
# Processing Record 23 of Set 30 | ketrzyn
# Processing Record 24 of Set 30 | amboise
# Processing Record 25 of Set 30 | bandarbeyla
# Processing Record 26 of Set 30 | turukhansk
# Processing Record 27 of Set 30 | kanevskaya
# Processing Record 28 of Set 30 | mecca
# Processing Record 29 of Set 30 | mata
# Processing Record 30 of Set 30 | borkenes
# Processing Record 31 of Set 30 | malpura
# Processing Record 32 of Set 30 | kafanchan
# Processing Record 33 of Set 30 | ilebo
# Processing Record 34 of Set 30 | kangaba
# Processing Record 35 of Set 30 | gigmoto
# Processing Record 36 of Set 30 | mehamn
# Processing Record 37 of Set 30 | kingston
# Processing Record 38 of Set 30 | chunskiy
# Processing Record 39 of Set 30 | do rud
# City not found. Skipping...
# Processing Record 40 of Set 30 | taunggyi
# Processing Record 41 of Set 30 | guilin
# Processing Record 42 of Set 30 | goias
# Processing Record 43 of Set 30 | alappuzha
# Processing Record 44 of Set 30 | bull savanna
# Processing Record 45 of Set 30 | kamiiso
# Processing Record 46 of Set 30 | saravan
# Processing Record 47 of Set 30 | lazaro cardenas
# Processing Record 48 of Set 30 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 30 | sai buri
# Processing Record 50 of Set 30 | douglas
# Processing Record 1 of Set 31 | tahe
# Processing Record 2 of Set 31 | naerbo
# Processing Record 3 of Set 31 | preveza
# Processing Record 4 of Set 31 | chara
# Processing Record 5 of Set 31 | boulder city
# Processing Record 6 of Set 31 | nata
# Processing Record 7 of Set 31 | eilenburg
# Processing Record 8 of Set 31 | la ronge
# Processing Record 9 of Set 31 | nishihara
# Processing Record 10 of Set 31 | farafenni
# Processing Record 11 of Set 31 | jardim
# Processing Record 12 of Set 31 | male
# Processing Record 13 of Set 31 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 31 | alakurtti
# Processing Record 15 of Set 31 | goroka
# Processing Record 16 of Set 31 | boende
# Processing Record 17 of Set 31 | mykhaylivka
# Processing Record 18 of Set 31 | yangliuqing
# Processing Record 19 of Set 31 | havelock
# Processing Record 20 of Set 31 | makat
# Processing Record 21 of Set 31 | tumaco
# Processing Record 22 of Set 31 | kawardha
# Processing Record 23 of Set 31 | bekhtery
# Processing Record 24 of Set 31 | gonbad-e qabus
# Processing Record 25 of Set 31 | hokitika
# Processing Record 26 of Set 31 | teguise
# Processing Record 27 of Set 31 | lar
# Processing Record 28 of Set 31 | warri
# Processing Record 29 of Set 31 | shakhtinsk
# Processing Record 30 of Set 31 | rio gallegos
# Processing Record 31 of Set 31 | kortkeros
# Processing Record 32 of Set 31 | ouallam
# Processing Record 33 of Set 31 | aripuana
# Processing Record 34 of Set 31 | negombo
# Processing Record 35 of Set 31 | voi
# Processing Record 36 of Set 31 | carndonagh
# Processing Record 37 of Set 31 | oistins
# Processing Record 38 of Set 31 | yeppoon
# Processing Record 39 of Set 31 | tungor
# Processing Record 40 of Set 31 | bayan
# Processing Record 41 of Set 31 | ngorongoro
# Processing Record 42 of Set 31 | mashhad
# Processing Record 43 of Set 31 | moyo
# Processing Record 44 of Set 31 | bagdarin
# Processing Record 45 of Set 31 | turayf
# Processing Record 46 of Set 31 | rocky mountain house
# Processing Record 47 of Set 31 | la palma
# Processing Record 48 of Set 31 | watsa
# Processing Record 49 of Set 31 | sao jose da coroa grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 733

# %%
city_data[1]
# Out:
# {'City': 'Ushuaia',
#  'Country': 'AR',
#  'Lat': -54.8,
#  'Lng': -68.3,
#  'Max Temp': 44.22,
#  'Humidity': 87,
#  'Cloudiness': 75,
#  'Wind Speed': 3.44,
#  'Current Weather': 'broken clouds'}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.all()
# Out:
# City                True
# Country             True
# Lat                 True
# Lng                 True
# Max Temp            True
# Humidity            True
# Cloudiness         False
# Wind Speed         False
# Current Weather     True
# dtype: bool

# %%
city_data_df
# Out:
#                          City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      Albany      US  42.6001  -73.9662     79.66        53
# 1                     Ushuaia      AR -54.8000  -68.3000     44.22        87
# 2                     Rikitea      PF -23.1203 -134.9692     73.98        79
# 3                   Salamiyah      SY  35.0113   37.0532     81.05        30
# 4                   Mahebourg      MU -20.4081   57.7000     70.09        83
# ..                        ...     ...      ...       ...       ...       ...
# 728                    Turayf      SA  31.6725   38.6637     86.25        48
# 729      Rocky Mountain House      CA  52.3668 -114.9188     75.31        57
# 730                  La Palma      US  33.8464 -118.0467    102.02        55
# 731                     Watsa      CD   3.0372   29.5355     64.31        98
# 732  Sao Jose Da Coroa Grande      BR  -8.8978  -35.1478     78.12        72
#
#      Cloudiness  Wind Speed Current Weather
# 0            23        3.02      few clouds
# 1            75        3.44   broken clouds
# 2            91       13.18      light rain
# 3             0        9.95       clear sky
# 4            75       21.85   moderate rain
# ..          ...         ...             ...
# 728           0       20.71       clear sky
# 729           0       11.50       clear sky
# 730          20        5.01      few clouds
# 731          91        1.28   moderate rain
# 732           1        6.46       clear sky
#
# [733 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

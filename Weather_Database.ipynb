# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random 1500 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. unpack our lat_lngs zip object into a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
# The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Weather": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sola
# Processing Record 2 of Set 1 | obo
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | khotyn
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | dagana
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | kalmunai
# Processing Record 12 of Set 1 | palmer
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | rezekne
# Processing Record 15 of Set 1 | vysokogornyy
# Processing Record 16 of Set 1 | general roca
# Processing Record 17 of Set 1 | kayerkan
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | beinamar
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | kalabo
# Processing Record 23 of Set 1 | riyadh
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | cayenne
# Processing Record 27 of Set 1 | severomuysk
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | tiarei
# Processing Record 30 of Set 1 | mount gambier
# Processing Record 31 of Set 1 | togur
# Processing Record 32 of Set 1 | wamba
# Processing Record 33 of Set 1 | zhezkazgan
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | guaruja
# Processing Record 37 of Set 1 | champasak
# Processing Record 38 of Set 1 | namatanai
# Processing Record 39 of Set 1 | alyangula
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | leshukonskoye
# Processing Record 42 of Set 1 | houma
# Processing Record 43 of Set 1 | calama
# Processing Record 44 of Set 1 | dhidhdhoo
# Processing Record 45 of Set 1 | shirokiy
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | uruguaiana
# Processing Record 1 of Set 2 | carupano
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | barentsburg
# Processing Record 5 of Set 2 | pacific grove
# Processing Record 6 of Set 2 | clyde river
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | ovsyanka
# Processing Record 11 of Set 2 | taolanaro
# Processing Record 12 of Set 2 | asau
# Processing Record 13 of Set 2 | riverton
# Processing Record 14 of Set 2 | almas
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | la grande
# Processing Record 18 of Set 2 | kavaratti
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | taltal
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | suntar
# Processing Record 24 of Set 2 | irituia
# Processing Record 25 of Set 2 | leh
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | half moon bay
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | barra do corda
# Processing Record 31 of Set 2 | padang
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | sao joao da barra
# Processing Record 34 of Set 2 | mwinilunga
# Processing Record 35 of Set 2 | tekeli
# Processing Record 36 of Set 2 | attawapiskat
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | coria
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | suhut
# Processing Record 41 of Set 2 | farafangana
# Processing Record 42 of Set 2 | chumikan
# Processing Record 43 of Set 2 | pisco
# Processing Record 44 of Set 2 | margate
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | great falls
# Processing Record 49 of Set 2 | sari
# Processing Record 50 of Set 2 | belmonte
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | namwala
# Processing Record 3 of Set 3 | fairbanks
# Processing Record 4 of Set 3 | henties bay
# Processing Record 5 of Set 3 | birjand
# Processing Record 6 of Set 3 | sisimiut
# Processing Record 7 of Set 3 | cairns
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | tiznit
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | belushya guba
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | salinopolis
# Processing Record 17 of Set 3 | abhar
# Processing Record 18 of Set 3 | cache creek
# Processing Record 19 of Set 3 | bridlington
# Processing Record 20 of Set 3 | sarangani
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | warqla
# Processing Record 23 of Set 3 | hailey
# Processing Record 24 of Set 3 | panjakent
# Processing Record 25 of Set 3 | ulaangom
# Processing Record 26 of Set 3 | buluang
# Processing Record 27 of Set 3 | shizilu
# Processing Record 28 of Set 3 | boo
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | deer lake
# Processing Record 32 of Set 3 | kismayo
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | butembo
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | port-cartier
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | zaragoza
# Processing Record 41 of Set 3 | sandpoint
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | karakol
# Processing Record 44 of Set 3 | katyuzhanka
# Processing Record 45 of Set 3 | mys shmidta
# Processing Record 46 of Set 3 | ulladulla
# Processing Record 47 of Set 3 | tomatlan
# Processing Record 48 of Set 3 | gravdal
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 50 of Set 3 | vila velha
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | nanzhou
# Processing Record 3 of Set 4 | kushima
# Processing Record 4 of Set 4 | inderborskiy
# Processing Record 5 of Set 4 | sentyabrskiy
# Processing Record 6 of Set 4 | soyo
# Processing Record 7 of Set 4 | dauriya
# Processing Record 8 of Set 4 | kenosha
# Processing Record 9 of Set 4 | presidente dutra
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | glenwood springs
# Processing Record 12 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | illoqqortoormiut
# Processing Record 16 of Set 4 | andenes
# Processing Record 17 of Set 4 | saint-louis
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | antofagasta
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | buala
# Processing Record 22 of Set 4 | puerto morazan
# Processing Record 23 of Set 4 | kaka
# Processing Record 24 of Set 4 | iriron
# Processing Record 25 of Set 4 | fairmont
# Processing Record 26 of Set 4 | oristano
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | araouane
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | rio gallegos
# Processing Record 31 of Set 4 | samarai
# Processing Record 32 of Set 4 | geraldton
# Processing Record 33 of Set 4 | arlit
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | sulangan
# Processing Record 36 of Set 4 | bad ems
# Processing Record 37 of Set 4 | humaita
# Processing Record 38 of Set 4 | husavik
# Processing Record 39 of Set 4 | alta floresta
# Processing Record 40 of Set 4 | tucuma
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | mahabaleshwar
# Processing Record 44 of Set 4 | pafos
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | koslan
# Processing Record 48 of Set 4 | lake city
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 50 of Set 4 | lac-megantic
# Processing Record 1 of Set 5 | zima
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | impfondo
# Processing Record 4 of Set 5 | malangali
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | nenjiang
# Processing Record 8 of Set 5 | chicama
# Processing Record 9 of Set 5 | atar
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | kholtoson
# Processing Record 13 of Set 5 | marcona
# Processing Record 14 of Set 5 | atuona
# Processing Record 15 of Set 5 | bargal
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | pijijiapan
# Processing Record 18 of Set 5 | pucallpa
# Processing Record 19 of Set 5 | nome
# Processing Record 20 of Set 5 | san pedro
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | namibe
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | puerto ayora
# Processing Record 25 of Set 5 | umarkot
# Processing Record 26 of Set 5 | jyvaskyla
# Processing Record 27 of Set 5 | veraval
# Processing Record 28 of Set 5 | montlucon
# Processing Record 29 of Set 5 | haileybury
# Processing Record 30 of Set 5 | dubovskoye
# Processing Record 31 of Set 5 | iwaki
# Processing Record 32 of Set 5 | nizhneyansk
# Processing Record 33 of Set 5 | klyuchi
# Processing Record 34 of Set 5 | haines junction
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | stonewall
# Processing Record 37 of Set 5 | yellowknife
# Processing Record 38 of Set 5 | grindavik
# Processing Record 39 of Set 5 | batemans bay
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | bireun
# Processing Record 42 of Set 5 | san julian
# Processing Record 43 of Set 5 | bima
# Processing Record 44 of Set 5 | pangnirtung
# Processing Record 45 of Set 5 | piacabucu
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | itoman
# Processing Record 48 of Set 5 | marzuq
# Processing Record 49 of Set 5 | kenai
# Processing Record 50 of Set 5 | grand river south east
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | bredasdorp
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | pombas
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | baie-comeau
# Processing Record 7 of Set 6 | chokurdakh
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | kirakira
# Processing Record 11 of Set 6 | naze
# Processing Record 12 of Set 6 | kahului
# Processing Record 13 of Set 6 | demirci
# Processing Record 14 of Set 6 | vestmanna
# Processing Record 15 of Set 6 | brownwood
# Processing Record 16 of Set 6 | buariki
# Processing Record 17 of Set 6 | ambovombe
# Processing Record 18 of Set 6 | tomelloso
# Processing Record 19 of Set 6 | pulaski
# Processing Record 20 of Set 6 | panama city
# Processing Record 21 of Set 6 | samusu
# Processing Record 22 of Set 6 | karaul
# Processing Record 23 of Set 6 | cozumel
# Processing Record 24 of Set 6 | khonuu
# Processing Record 25 of Set 6 | bathsheba
# Processing Record 26 of Set 6 | tilichiki
# Processing Record 27 of Set 6 | dolores
# Processing Record 28 of Set 6 | hay river
# Processing Record 29 of Set 6 | palasa
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | cliza
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | viligili
# Processing Record 35 of Set 6 | cerrito
# Processing Record 36 of Set 6 | port alfred
# Processing Record 37 of Set 6 | discovery bay
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | akcaabat
# Processing Record 40 of Set 6 | vieste
# Processing Record 41 of Set 6 | raudeberg
# Processing Record 42 of Set 6 | kudahuvadhoo
# Processing Record 43 of Set 6 | bousso
# Processing Record 44 of Set 6 | praia da vitoria
# Processing Record 45 of Set 6 | talawdi
# Processing Record 46 of Set 6 | villa del rosario
# Processing Record 47 of Set 6 | copiapo
# Processing Record 48 of Set 6 | parras
# Processing Record 49 of Set 6 | batagay-alyta
# Processing Record 50 of Set 6 | quatre cocos
# Processing Record 1 of Set 7 | tigil
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | matameye
# Processing Record 4 of Set 7 | simbahan
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | yenagoa
# Processing Record 7 of Set 7 | muravlenko
# Processing Record 8 of Set 7 | utiroa
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | singkang
# Processing Record 11 of Set 7 | marapanim
# Processing Record 12 of Set 7 | moose factory
# Processing Record 13 of Set 7 | vanimo
# Processing Record 14 of Set 7 | saint-leu
# Processing Record 15 of Set 7 | beloha
# Processing Record 16 of Set 7 | lagunas
# Processing Record 17 of Set 7 | tsihombe
# Processing Record 18 of Set 7 | havre-saint-pierre
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | concordia
# Processing Record 21 of Set 7 | hailar
# Processing Record 22 of Set 7 | grand gaube
# Processing Record 23 of Set 7 | thunder bay
# Processing Record 24 of Set 7 | tura
# Processing Record 25 of Set 7 | bandarbeyla
# Processing Record 26 of Set 7 | shaoyang
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | guayaramerin
# Processing Record 29 of Set 7 | payo
# Processing Record 30 of Set 7 | carbonia
# Processing Record 31 of Set 7 | avera
# Processing Record 32 of Set 7 | livramento
# Processing Record 33 of Set 7 | khalkhal
# Processing Record 34 of Set 7 | asfi
# Processing Record 35 of Set 7 | kieta
# Processing Record 36 of Set 7 | aquiraz
# Processing Record 37 of Set 7 | manyana
# Processing Record 38 of Set 7 | san policarpo
# Processing Record 39 of Set 7 | gryazovets
# Processing Record 40 of Set 7 | znamenskoye
# Processing Record 41 of Set 7 | vadso
# Processing Record 42 of Set 7 | calatayud
# Processing Record 43 of Set 7 | marsh harbour
# Processing Record 44 of Set 7 | doctor juan manuel frutos
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | hamilton
# Processing Record 47 of Set 7 | dolbeau
# Processing Record 48 of Set 7 | lasa
# Processing Record 49 of Set 7 | karratha
# Processing Record 50 of Set 7 | garowe
# Processing Record 1 of Set 8 | ust-omchug
# Processing Record 2 of Set 8 | yantzaza
# Processing Record 3 of Set 8 | honningsvag
# Processing Record 4 of Set 8 | isla mujeres
# Processing Record 5 of Set 8 | tieling
# Processing Record 6 of Set 8 | umzimvubu
# Processing Record 7 of Set 8 | macouria
# Processing Record 8 of Set 8 | bubaque
# Processing Record 9 of Set 8 | wenzhou
# Processing Record 10 of Set 8 | khorramabad
# Processing Record 11 of Set 8 | yertsevo
# Processing Record 12 of Set 8 | viisoara
# Processing Record 13 of Set 8 | zhovkva
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | ngukurr
# Processing Record 16 of Set 8 | hambantota
# Processing Record 17 of Set 8 | coolum beach
# Processing Record 18 of Set 8 | souillac
# Processing Record 19 of Set 8 | pekan
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | chalmette
# Processing Record 22 of Set 8 | eskisehir
# Processing Record 23 of Set 8 | jalu
# Processing Record 24 of Set 8 | salina
# Processing Record 25 of Set 8 | ballina
# Processing Record 26 of Set 8 | casablanca
# Processing Record 27 of Set 8 | mendi
# Processing Record 28 of Set 8 | belen
# Processing Record 29 of Set 8 | dunedin
# Processing Record 30 of Set 8 | kazanskaya
# Processing Record 31 of Set 8 | castro
# Processing Record 32 of Set 8 | dalvik
# Processing Record 33 of Set 8 | zhangye
# Processing Record 34 of Set 8 | deputatskiy
# Processing Record 35 of Set 8 | lemesos
# Processing Record 36 of Set 8 | inverell
# Processing Record 37 of Set 8 | caravelas
# Processing Record 38 of Set 8 | khandyga
# Processing Record 39 of Set 8 | vaitupu
# Processing Record 40 of Set 8 | lagos
# Processing Record 41 of Set 8 | bengkulu
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | lagoa
# Processing Record 44 of Set 8 | marawi
# Processing Record 45 of Set 8 | alekseyevsk
# Processing Record 46 of Set 8 | batagay
# Processing Record 47 of Set 8 | sampit
# Processing Record 48 of Set 8 | kamenka
# Processing Record 49 of Set 8 | rock sound
# Processing Record 50 of Set 8 | kragero
# Processing Record 1 of Set 9 | jumla
# Processing Record 2 of Set 9 | duki
# Processing Record 3 of Set 9 | currais novos
# Processing Record 4 of Set 9 | horn lake
# Processing Record 5 of Set 9 | potgietersrus
# Processing Record 6 of Set 9 | san cosme y damian
# Processing Record 7 of Set 9 | conchas
# Processing Record 8 of Set 9 | guane
# Processing Record 9 of Set 9 | nanakuli
# Processing Record 10 of Set 9 | sumbawa
# Processing Record 11 of Set 9 | epe
# Processing Record 12 of Set 9 | tuburan
# Processing Record 13 of Set 9 | kashi
# Processing Record 14 of Set 9 | barawe
# Processing Record 15 of Set 9 | tazovskiy
# Processing Record 16 of Set 9 | lavumisa
# Processing Record 17 of Set 9 | saint-joseph
# Processing Record 18 of Set 9 | ocos
# Processing Record 19 of Set 9 | utica
# Processing Record 20 of Set 9 | sun prairie
# Processing Record 21 of Set 9 | altay
# Processing Record 22 of Set 9 | wanning
# Processing Record 23 of Set 9 | la primavera
# Processing Record 24 of Set 9 | umm durman
# Processing Record 25 of Set 9 | muros
# Processing Record 26 of Set 9 | tessalit
# Processing Record 27 of Set 9 | torbay
# Processing Record 28 of Set 9 | visby
# Processing Record 29 of Set 9 | filingue
# Processing Record 30 of Set 9 | tam ky
# Processing Record 31 of Set 9 | talara
# Processing Record 32 of Set 9 | innisfail
# Processing Record 33 of Set 9 | sankt veit
# Processing Record 34 of Set 9 | lakes entrance
# Processing Record 35 of Set 9 | natal
# Processing Record 36 of Set 9 | gizo
# Processing Record 37 of Set 9 | touros
# Processing Record 38 of Set 9 | manta
# Processing Record 39 of Set 9 | athens
# Processing Record 40 of Set 9 | berezovyy
# Processing Record 41 of Set 9 | namanga
# Processing Record 42 of Set 9 | plettenberg bay
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | mersing
# Processing Record 45 of Set 9 | camargo
# Processing Record 46 of Set 9 | pevek
# Processing Record 47 of Set 9 | iqaluit
# Processing Record 48 of Set 9 | martinsburg
# Processing Record 49 of Set 9 | bang khla
# Processing Record 50 of Set 9 | east london
# Processing Record 1 of Set 10 | lata
# Processing Record 2 of Set 10 | haibowan
# Processing Record 3 of Set 10 | bata
# Processing Record 4 of Set 10 | suoyarvi
# Processing Record 5 of Set 10 | korgen
# Processing Record 6 of Set 10 | belyy yar
# Processing Record 7 of Set 10 | lannion
# Processing Record 8 of Set 10 | swan river
# Processing Record 9 of Set 10 | bogalusa
# Processing Record 10 of Set 10 | acapulco
# Processing Record 11 of Set 10 | tambacounda
# Processing Record 12 of Set 10 | nilokheri
# Processing Record 13 of Set 10 | halalo
# Processing Record 14 of Set 10 | derzhavinsk
# Processing Record 15 of Set 10 | novyye lyady
# Processing Record 16 of Set 10 | oriximina
# Processing Record 17 of Set 10 | saleaula
# Processing Record 18 of Set 10 | gorom-gorom
# Processing Record 19 of Set 10 | mugur-aksy
# Processing Record 20 of Set 10 | hervey bay
# Processing Record 21 of Set 10 | gawler
# Processing Record 22 of Set 10 | barcelona
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | camacha
# Processing Record 25 of Set 10 | bolshoy tsaryn
# Processing Record 26 of Set 10 | lazaro cardenas
# Processing Record 27 of Set 10 | pueblo
# Processing Record 28 of Set 10 | tiksi
# Processing Record 29 of Set 10 | penzance
# Processing Record 30 of Set 10 | yakeshi
# Processing Record 31 of Set 10 | bilma
# Processing Record 32 of Set 10 | ugoofaaru
# Processing Record 33 of Set 10 | kajaani
# Processing Record 34 of Set 10 | gardan diwal
# Processing Record 35 of Set 10 | mudigere
# Processing Record 36 of Set 10 | hokitika
# Processing Record 37 of Set 10 | trelew
# Processing Record 38 of Set 10 | fort nelson
# Processing Record 39 of Set 10 | mount isa
# Processing Record 40 of Set 10 | griffith
# Processing Record 41 of Set 10 | esperance
# Processing Record 42 of Set 10 | rochester
# Processing Record 43 of Set 10 | quesnel
# Processing Record 44 of Set 10 | erenhot
# Processing Record 45 of Set 10 | burnie
# Processing Record 46 of Set 10 | cap malheureux
# Processing Record 47 of Set 10 | zaysan
# Processing Record 48 of Set 10 | praia
# Processing Record 49 of Set 10 | biltine
# Processing Record 50 of Set 10 | tabou
# Processing Record 1 of Set 11 | tarudant
# Processing Record 2 of Set 11 | gazanjyk
# Processing Record 3 of Set 11 | palora
# Processing Record 4 of Set 11 | tres arroyos
# Processing Record 5 of Set 11 | gdynia
# Processing Record 6 of Set 11 | mareeba
# Processing Record 7 of Set 11 | pokhara
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | oksfjord
# Processing Record 10 of Set 11 | amderma
# Processing Record 11 of Set 11 | roald
# Processing Record 12 of Set 11 | san nicolas
# Processing Record 13 of Set 11 | karamea
# Processing Record 14 of Set 11 | dayong
# Processing Record 15 of Set 11 | severodvinsk
# Processing Record 16 of Set 11 | lolua
# Processing Record 17 of Set 11 | charters towers
# Processing Record 18 of Set 11 | nouakchott
# Processing Record 19 of Set 11 | bocas del toro
# Processing Record 20 of Set 11 | lensk
# Processing Record 21 of Set 11 | colac
# Processing Record 22 of Set 11 | harnosand
# Processing Record 23 of Set 11 | ozark
# Processing Record 24 of Set 11 | teguise
# Processing Record 25 of Set 11 | shelburne
# Processing Record 26 of Set 11 | paamiut
# Processing Record 27 of Set 11 | saint anthony
# Processing Record 28 of Set 11 | bow island
# Processing Record 29 of Set 11 | kyra
# Processing Record 30 of Set 11 | buqayq
# Processing Record 31 of Set 11 | makakilo city
# Processing Record 32 of Set 11 | makrana
# Processing Record 33 of Set 11 | wewak
# Processing Record 34 of Set 11 | shablykino
# Processing Record 35 of Set 11 | skagastrond
# Processing Record 36 of Set 11 | mount darwin
# Processing Record 37 of Set 11 | diffa
# Processing Record 38 of Set 11 | port augusta
# Processing Record 39 of Set 11 | patrocinio
# Processing Record 40 of Set 11 | qaqortoq
# Processing Record 41 of Set 11 | methoni
# Processing Record 42 of Set 11 | ozimek
# Processing Record 43 of Set 11 | tombouctou
# Processing Record 44 of Set 11 | abu kamal
# Processing Record 45 of Set 11 | shar
# Processing Record 46 of Set 11 | staryy krym
# Processing Record 47 of Set 11 | blankenberge
# Processing Record 48 of Set 11 | thinadhoo
# Processing Record 49 of Set 11 | sobolevo
# Processing Record 50 of Set 11 | iwanai
# Processing Record 1 of Set 12 | boyolangu
# Processing Record 2 of Set 12 | hamadan
# Processing Record 3 of Set 12 | neiafu
# Processing Record 4 of Set 12 | phan thiet
# Processing Record 5 of Set 12 | panaba
# Processing Record 6 of Set 12 | tignere
# Processing Record 7 of Set 12 | kalevala
# Processing Record 8 of Set 12 | harindanga
# Processing Record 9 of Set 12 | santa marta
# Processing Record 10 of Set 12 | tateyama
# Processing Record 11 of Set 12 | beyneu
# Processing Record 12 of Set 12 | winchester
# Processing Record 13 of Set 12 | abbeville
# Processing Record 14 of Set 12 | aswan
# Processing Record 15 of Set 12 | qasigiannguit
# Processing Record 16 of Set 12 | aranos
# Processing Record 17 of Set 12 | horta
# Processing Record 18 of Set 12 | aksha
# Processing Record 19 of Set 12 | tighina
# Processing Record 20 of Set 12 | bafq
# Processing Record 21 of Set 12 | pandan
# Processing Record 22 of Set 12 | murgud
# Processing Record 23 of Set 12 | kaabong
# Processing Record 24 of Set 12 | college
# Processing Record 25 of Set 12 | talaya
# Processing Record 26 of Set 12 | vernon
# Processing Record 27 of Set 12 | dicabisagan
# Processing Record 28 of Set 12 | birobidzhan
# Processing Record 29 of Set 12 | saleilua
# Processing Record 30 of Set 12 | bilibino
# Processing Record 31 of Set 12 | ondorhaan
# Processing Record 32 of Set 12 | broken hill
# Processing Record 33 of Set 12 | lady frere
# Processing Record 34 of Set 12 | zubtsov
# Processing Record 35 of Set 12 | matagami
# Processing Record 36 of Set 12 | rivadavia
# Processing Record 37 of Set 12 | sabang
# Processing Record 38 of Set 12 | san juan
# Processing Record 39 of Set 12 | oistins
# Processing Record 40 of Set 12 | yerani
# Processing Record 41 of Set 12 | makaha
# Processing Record 42 of Set 12 | mizdah
# Processing Record 43 of Set 12 | najran
# Processing Record 44 of Set 12 | dingle
# Processing Record 45 of Set 12 | cuauhtemoc
# Processing Record 46 of Set 12 | darhan
# Processing Record 47 of Set 12 | lahad datu
# Processing Record 48 of Set 12 | flinders
# Processing Record 49 of Set 12 | texarkana
# Processing Record 50 of Set 12 | cockburn town
# Processing Record 1 of Set 13 | morehead
# Processing Record 2 of Set 13 | haapiti
# Processing Record 3 of Set 13 | santiago de compostela
# Processing Record 4 of Set 13 | karatau
# Processing Record 5 of Set 13 | rovaniemi
# Processing Record 6 of Set 13 | port hedland
# Processing Record 7 of Set 13 | pangai
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | kaeo
# Processing Record 10 of Set 13 | lieksa
# Processing Record 11 of Set 13 | lalmohan
# Processing Record 12 of Set 13 | alekseyevka
# Processing Record 13 of Set 13 | khvastovichi
# Processing Record 14 of Set 13 | luba
# Processing Record 15 of Set 13 | saveh
# Processing Record 16 of Set 13 | formosa
# Processing Record 17 of Set 13 | bentiu
# Processing Record 18 of Set 13 | dongying
# Processing Record 19 of Set 13 | bukene
# Processing Record 20 of Set 13 | lhokseumawe
# Processing Record 21 of Set 13 | colon
# Processing Record 22 of Set 13 | urumqi
# Processing Record 23 of Set 13 | dong xoai
# Processing Record 24 of Set 13 | funtua
# Processing Record 25 of Set 13 | ormstown
# Processing Record 26 of Set 13 | oxapampa
# Processing Record 27 of Set 13 | praya
# Processing Record 28 of Set 13 | sakakah
# Processing Record 29 of Set 13 | high rock
# Processing Record 30 of Set 13 | kuhdasht
# Processing Record 31 of Set 13 | lenger
# Processing Record 32 of Set 13 | shubarkuduk
# Processing Record 33 of Set 13 | saint pete beach
# Processing Record 34 of Set 13 | maimon
# Processing Record 35 of Set 13 | necochea
# Processing Record 36 of Set 13 | bawku
# Processing Record 37 of Set 13 | popondetta
# Processing Record 38 of Set 13 | shimoda
# Processing Record 39 of Set 13 | khani
# Processing Record 40 of Set 13 | bratsk
# Processing Record 41 of Set 13 | jaisinghnagar
# Processing Record 42 of Set 13 | dombarovskiy
# Processing Record 43 of Set 13 | port saint lucie
# Processing Record 44 of Set 13 | teruel
# Processing Record 45 of Set 13 | weiser
# Processing Record 46 of Set 13 | batsfjord
# Processing Record 47 of Set 13 | solnechnyy
# Processing Record 48 of Set 13 | north bend
# Processing Record 49 of Set 13 | rawson
# Processing Record 50 of Set 13 | chinsali
# Processing Record 1 of Set 14 | muromtsevo
# Processing Record 2 of Set 14 | isangel
# Processing Record 3 of Set 14 | bowen
# Processing Record 4 of Set 14 | arvika
# Processing Record 5 of Set 14 | tommot
# Processing Record 6 of Set 14 | hegang
# Processing Record 7 of Set 14 | mfou
# Processing Record 8 of Set 14 | maarianhamina
# Processing Record 9 of Set 14 | sarkand
# Processing Record 10 of Set 14 | radhanpur
# Processing Record 11 of Set 14 | kastamonu
# Processing Record 12 of Set 14 | luanda
# Processing Record 13 of Set 14 | atikokan
# Processing Record 14 of Set 14 | nazca
# Processing Record 15 of Set 14 | uyuni
# Processing Record 16 of Set 14 | xinzhi
# Processing Record 17 of Set 14 | kupang
# Processing Record 18 of Set 14 | baykit
# Processing Record 19 of Set 14 | camabatela
# Processing Record 20 of Set 14 | conceicao da barra
# Processing Record 21 of Set 14 | sheridan
# Processing Record 22 of Set 14 | saint-andre-avellin
# Processing Record 23 of Set 14 | pasighat
# Processing Record 24 of Set 14 | high prairie
# Processing Record 25 of Set 14 | udayagiri
# Processing Record 26 of Set 14 | punta alta
# Processing Record 27 of Set 14 | jaleswar
# Processing Record 28 of Set 14 | turukhansk
# Processing Record 29 of Set 14 | el sauce
# Processing Record 30 of Set 14 | kralendijk
# Processing Record 31 of Set 14 | effingham
# Processing Record 32 of Set 14 | sarahan
# Processing Record 33 of Set 14 | yurginskoye
# Processing Record 34 of Set 14 | kabinda
# Processing Record 35 of Set 14 | bosaso
# Processing Record 36 of Set 14 | burica
# Processing Record 37 of Set 14 | tabiauea
# Processing Record 38 of Set 14 | akdepe
# Processing Record 39 of Set 14 | yinchuan
# Processing Record 40 of Set 14 | bulgan
# Processing Record 41 of Set 14 | katherine
# Processing Record 42 of Set 14 | sur
# Processing Record 43 of Set 14 | balkhash
# Processing Record 44 of Set 14 | balykshi
# Processing Record 45 of Set 14 | varanasi
# Processing Record 46 of Set 14 | alofi
# Processing Record 47 of Set 14 | newark
# Processing Record 48 of Set 14 | herat
# Processing Record 49 of Set 14 | bunog
# Processing Record 50 of Set 14 | alice springs
# Processing Record 1 of Set 15 | vaitape
# Processing Record 2 of Set 15 | seoul
# Processing Record 3 of Set 15 | medicine hat
# Processing Record 4 of Set 15 | ha noi
# Processing Record 5 of Set 15 | robertsport
# Processing Record 6 of Set 15 | presidencia roque saenz pena
# Processing Record 7 of Set 15 | hanko
# Processing Record 8 of Set 15 | vila
# Processing Record 9 of Set 15 | camacupa
# Processing Record 10 of Set 15 | ascension
# Processing Record 11 of Set 15 | tupik
# Processing Record 12 of Set 15 | crib point
# Processing Record 13 of Set 15 | merauke
# Processing Record 14 of Set 15 | wundanyi
# Processing Record 15 of Set 15 | mangrol
# Processing Record 16 of Set 15 | tumannyy
# Processing Record 17 of Set 15 | hirara
# Processing Record 18 of Set 15 | samalaeulu
# Processing Record 19 of Set 15 | bud
# Processing Record 20 of Set 15 | wulanhaote
# Processing Record 21 of Set 15 | paita
# Processing Record 22 of Set 15 | port antonio
# Processing Record 23 of Set 15 | puerto escondido
# Processing Record 24 of Set 15 | thurso
# Processing Record 25 of Set 15 | de-kastri
# Processing Record 26 of Set 15 | puerto madryn
# Processing Record 27 of Set 15 | tezu
# Processing Record 28 of Set 15 | itarema
# Processing Record 29 of Set 15 | pringsewu
# Processing Record 30 of Set 15 | kardymovo
# Processing Record 31 of Set 15 | butte
# Processing Record 32 of Set 15 | sudbury
# Processing Record 33 of Set 15 | pauini
# Processing Record 34 of Set 15 | trairi
# Processing Record 35 of Set 15 | lufilufi
# Processing Record 36 of Set 15 | komsomolskiy
# Processing Record 37 of Set 15 | chastoozerye
# Processing Record 38 of Set 15 | moyo
# Processing Record 39 of Set 15 | gostilitsy
# Processing Record 40 of Set 15 | luwuk
# Processing Record 41 of Set 15 | la palma
# Processing Record 42 of Set 15 | iquitos
# Processing Record 43 of Set 15 | taboc
# Processing Record 44 of Set 15 | yerbogachen
# Processing Record 45 of Set 15 | prado
# Processing Record 46 of Set 15 | royan
# Processing Record 47 of Set 15 | hualmay
# Processing Record 48 of Set 15 | tubruq
# Processing Record 49 of Set 15 | boa vista
# Processing Record 50 of Set 15 | ust-nera
# Processing Record 1 of Set 16 | willmar
# Processing Record 2 of Set 16 | varzea da palma
# Processing Record 3 of Set 16 | rio grande
# Processing Record 4 of Set 16 | santiago del estero
# Processing Record 5 of Set 16 | magole
# Processing Record 6 of Set 16 | ahipara
# Processing Record 7 of Set 16 | tarcau
# Processing Record 8 of Set 16 | antsohihy
# Processing Record 9 of Set 16 | cocula
# Processing Record 10 of Set 16 | jiroft
# Processing Record 11 of Set 16 | novo cruzeiro
# Processing Record 12 of Set 16 | viedma
# Processing Record 13 of Set 16 | cascais
# Processing Record 14 of Set 16 | ranong
# Processing Record 15 of Set 16 | shache
# Processing Record 16 of Set 16 | ellsworth
# Processing Record 17 of Set 16 | kaohsiung
# Processing Record 18 of Set 16 | benatky nad jizerou
# Processing Record 19 of Set 16 | khamgaon
# Processing Record 20 of Set 16 | tawkar
# Processing Record 21 of Set 16 | acajutla
# Processing Record 22 of Set 16 | sorland
# Processing Record 23 of Set 16 | nakamura
# Processing Record 24 of Set 16 | debre sina
# Processing Record 25 of Set 16 | pakxan
# Processing Record 26 of Set 16 | maicao
# Processing Record 27 of Set 16 | sept-iles
# Processing Record 28 of Set 16 | brae
# Processing Record 29 of Set 16 | bangkalan
# Processing Record 30 of Set 16 | lima
# Processing Record 31 of Set 16 | sola
# Processing Record 32 of Set 16 | obo
# Processing Record 33 of Set 16 | hermanus
# Processing Record 34 of Set 16 | provideniya
# Processing Record 35 of Set 16 | khotyn
# Processing Record 36 of Set 16 | albany
# Processing Record 37 of Set 16 | ancud
# Processing Record 38 of Set 16 | dagana
# Processing Record 39 of Set 16 | avarua
# Processing Record 40 of Set 16 | port lincoln
# Processing Record 41 of Set 16 | kalmunai
# Processing Record 42 of Set 16 | palmer
# Processing Record 43 of Set 16 | norman wells
# Processing Record 44 of Set 16 | rezekne
# Processing Record 45 of Set 16 | vysokogornyy
# Processing Record 46 of Set 16 | general roca
# Processing Record 47 of Set 16 | kayerkan
# Processing Record 48 of Set 16 | upernavik
# Processing Record 49 of Set 16 | beinamar
# Processing Record 50 of Set 16 | rikitea
# Processing Record 51 of Set 16 | cabo san lucas
# Processing Record 52 of Set 16 | kalabo
# Processing Record 53 of Set 16 | riyadh
# Processing Record 54 of Set 16 | chuy
# Processing Record 55 of Set 16 | bambous virieux
# Processing Record 56 of Set 16 | cayenne
# Processing Record 57 of Set 16 | severomuysk
# Processing Record 58 of Set 16 | victoria
# Processing Record 59 of Set 16 | tiarei
# Processing Record 60 of Set 16 | mount gambier
# Processing Record 61 of Set 16 | togur
# Processing Record 62 of Set 16 | wamba
# Processing Record 63 of Set 16 | zhezkazgan
# Processing Record 64 of Set 16 | codrington
# Processing Record 65 of Set 16 | cape town
# Processing Record 66 of Set 16 | guaruja
# Processing Record 67 of Set 16 | champasak
# Processing Record 68 of Set 16 | namatanai
# Processing Record 69 of Set 16 | alyangula
# Processing Record 70 of Set 16 | jamestown
# Processing Record 71 of Set 16 | leshukonskoye
# Processing Record 72 of Set 16 | houma
# Processing Record 73 of Set 16 | calama
# Processing Record 74 of Set 16 | dhidhdhoo
# Processing Record 75 of Set 16 | shirokiy
# Processing Record 76 of Set 16 | kapaa
# Processing Record 77 of Set 16 | mataura
# Processing Record 78 of Set 16 | fortuna
# Processing Record 79 of Set 16 | ribeira grande
# Processing Record 80 of Set 16 | uruguaiana
# Processing Record 1 of Set 17 | carupano
# Processing Record 2 of Set 17 | khatanga
# Processing Record 3 of Set 17 | severo-kurilsk
# Processing Record 4 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 17 | pacific grove
# Processing Record 6 of Set 17 | clyde river
# Processing Record 7 of Set 17 | airai
# Processing Record 8 of Set 17 | vaini
# Processing Record 9 of Set 17 | saint-philippe
# Processing Record 10 of Set 17 | ovsyanka
# Processing Record 11 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 17 | asau
# Processing Record 13 of Set 17 | riverton
# Processing Record 14 of Set 17 | almas
# Processing Record 15 of Set 17 | barrow
# Processing Record 16 of Set 17 | bluff
# Processing Record 17 of Set 17 | la grande
# Processing Record 18 of Set 17 | kavaratti
# Processing Record 19 of Set 17 | ushuaia
# Processing Record 20 of Set 17 | new norfolk
# Processing Record 21 of Set 17 | taltal
# Processing Record 22 of Set 17 | ilulissat
# Processing Record 23 of Set 17 | suntar
# Processing Record 24 of Set 17 | irituia
# Processing Record 25 of Set 17 | leh
# Processing Record 26 of Set 17 | georgetown
# Processing Record 27 of Set 17 | lebu
# Processing Record 28 of Set 17 | half moon bay
# Processing Record 29 of Set 17 | leningradskiy
# Processing Record 30 of Set 17 | barra do corda
# Processing Record 31 of Set 17 | padang
# Processing Record 32 of Set 17 | lavrentiya
# Processing Record 33 of Set 17 | sao joao da barra
# Processing Record 34 of Set 17 | mwinilunga
# Processing Record 35 of Set 17 | tekeli
# Processing Record 36 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 17 | hilo
# Processing Record 38 of Set 17 | coria
# Processing Record 39 of Set 17 | tuatapere
# Processing Record 40 of Set 17 | suhut
# Processing Record 41 of Set 17 | farafangana
# Processing Record 42 of Set 17 | chumikan
# Processing Record 43 of Set 17 | pisco
# Processing Record 44 of Set 17 | margate
# Processing Record 45 of Set 17 | mahebourg
# Processing Record 46 of Set 17 | vao
# Processing Record 47 of Set 17 | punta arenas
# Processing Record 48 of Set 17 | great falls
# Processing Record 49 of Set 17 | sari
# Processing Record 50 of Set 17 | belmonte
# Processing Record 1 of Set 18 | busselton
# Processing Record 2 of Set 18 | namwala
# Processing Record 3 of Set 18 | fairbanks
# Processing Record 4 of Set 18 | henties bay
# Processing Record 5 of Set 18 | birjand
# Processing Record 6 of Set 18 | sisimiut
# Processing Record 7 of Set 18 | cairns
# Processing Record 8 of Set 18 | hami
# Processing Record 9 of Set 18 | tiznit
# Processing Record 10 of Set 18 | ponta do sol
# Processing Record 11 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 18 | tasiilaq
# Processing Record 13 of Set 18 | qaanaaq
# Processing Record 14 of Set 18 | saint george
# Processing Record 15 of Set 18 | thompson
# Processing Record 16 of Set 18 | salinopolis
# Processing Record 17 of Set 18 | abhar
# Processing Record 18 of Set 18 | cache creek
# Processing Record 19 of Set 18 | bridlington
# Processing Record 20 of Set 18 | sarangani
# Processing Record 21 of Set 18 | okhotsk
# Processing Record 22 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 18 | hailey
# Processing Record 24 of Set 18 | panjakent
# Processing Record 25 of Set 18 | ulaangom
# Processing Record 26 of Set 18 | buluang
# Processing Record 27 of Set 18 | shizilu
# Processing Record 28 of Set 18 | boo
# Processing Record 29 of Set 18 | guerrero negro
# Processing Record 30 of Set 18 | hobart
# Processing Record 31 of Set 18 | deer lake
# Processing Record 32 of Set 18 | kismayo
# Processing Record 33 of Set 18 | nanortalik
# Processing Record 34 of Set 18 | butaritari
# Processing Record 35 of Set 18 | kodiak
# Processing Record 36 of Set 18 | butembo
# Processing Record 37 of Set 18 | port elizabeth
# Processing Record 38 of Set 18 | port-cartier
# Processing Record 39 of Set 18 | arraial do cabo
# Processing Record 40 of Set 18 | zaragoza
# Processing Record 41 of Set 18 | sandpoint
# Processing Record 42 of Set 18 | carnarvon
# Processing Record 43 of Set 18 | karakol
# Processing Record 44 of Set 18 | katyuzhanka
# Processing Record 45 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 18 | ulladulla
# Processing Record 47 of Set 18 | tomatlan
# Processing Record 48 of Set 18 | gravdal
# Processing Record 49 of Set 18 | saskylakh
# Processing Record 50 of Set 18 | vila velha
# Processing Record 1 of Set 19 | tuktoyaktuk
# Processing Record 2 of Set 19 | nanzhou
# Processing Record 3 of Set 19 | kushima
# Processing Record 4 of Set 19 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 19 | soyo
# Processing Record 7 of Set 19 | dauriya
# Processing Record 8 of Set 19 | kenosha
# Processing Record 9 of Set 19 | presidente dutra
# Processing Record 10 of Set 19 | constitucion
# Processing Record 11 of Set 19 | glenwood springs
# Processing Record 12 of Set 19 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 19 | sitka
# Processing Record 14 of Set 19 | klaksvik
# Processing Record 15 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 19 | andenes
# Processing Record 17 of Set 19 | saint-louis
# Processing Record 18 of Set 19 | hithadhoo
# Processing Record 19 of Set 19 | antofagasta
# Processing Record 20 of Set 19 | talnakh
# Processing Record 21 of Set 19 | buala
# Processing Record 22 of Set 19 | puerto morazan
# Processing Record 23 of Set 19 | kaka
# Processing Record 24 of Set 19 | iriron
# City not found. Skipping...
# Processing Record 25 of Set 19 | fairmont
# Processing Record 26 of Set 19 | oristano
# Processing Record 27 of Set 19 | bethel
# Processing Record 28 of Set 19 | araouane
# Processing Record 29 of Set 19 | sinnamary
# Processing Record 30 of Set 19 | rio gallegos
# Processing Record 31 of Set 19 | samarai
# Processing Record 32 of Set 19 | geraldton
# Processing Record 33 of Set 19 | arlit
# Processing Record 34 of Set 19 | kaitangata
# Processing Record 35 of Set 19 | sulangan
# Processing Record 36 of Set 19 | bad ems
# Processing Record 37 of Set 19 | humaita
# Processing Record 38 of Set 19 | husavik
# Processing Record 39 of Set 19 | alta floresta
# Processing Record 40 of Set 19 | tucuma
# Processing Record 41 of Set 19 | dikson
# Processing Record 42 of Set 19 | mar del plata
# Processing Record 43 of Set 19 | mahabaleshwar
# Processing Record 44 of Set 19 | pafos
# Processing Record 45 of Set 19 | kavieng
# Processing Record 46 of Set 19 | vardo
# Processing Record 47 of Set 19 | koslan
# Processing Record 48 of Set 19 | lake city
# Processing Record 49 of Set 19 | longyearbyen
# Processing Record 50 of Set 19 | lac-megantic
# Processing Record 1 of Set 20 | zima
# Processing Record 2 of Set 20 | cidreira
# Processing Record 3 of Set 20 | impfondo
# Processing Record 4 of Set 20 | malangali
# Processing Record 5 of Set 20 | meulaboh
# Processing Record 6 of Set 20 | narsaq
# Processing Record 7 of Set 20 | nenjiang
# Processing Record 8 of Set 20 | chicama
# Processing Record 9 of Set 20 | atar
# Processing Record 10 of Set 20 | lorengau
# Processing Record 11 of Set 20 | coquimbo
# Processing Record 12 of Set 20 | kholtoson
# Processing Record 13 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 20 | atuona
# Processing Record 15 of Set 20 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 20 | coihaique
# Processing Record 17 of Set 20 | pijijiapan
# Processing Record 18 of Set 20 | pucallpa
# Processing Record 19 of Set 20 | nome
# Processing Record 20 of Set 20 | san pedro
# Processing Record 21 of Set 20 | portland
# Processing Record 22 of Set 20 | namibe
# Processing Record 23 of Set 20 | nikolskoye
# Processing Record 24 of Set 20 | puerto ayora
# Processing Record 25 of Set 20 | umarkot
# Processing Record 26 of Set 20 | jyvaskyla
# Processing Record 27 of Set 20 | veraval
# Processing Record 28 of Set 20 | montlucon
# Processing Record 29 of Set 20 | haileybury
# Processing Record 30 of Set 20 | dubovskoye
# Processing Record 31 of Set 20 | iwaki
# Processing Record 32 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 20 | klyuchi
# Processing Record 34 of Set 20 | haines junction
# Processing Record 35 of Set 20 | champerico
# Processing Record 36 of Set 20 | stonewall
# Processing Record 37 of Set 20 | yellowknife
# Processing Record 38 of Set 20 | grindavik
# Processing Record 39 of Set 20 | batemans bay
# Processing Record 40 of Set 20 | lompoc
# Processing Record 41 of Set 20 | bireun
# Processing Record 42 of Set 20 | san julian
# Processing Record 43 of Set 20 | bima
# Processing Record 44 of Set 20 | pangnirtung
# Processing Record 45 of Set 20 | piacabucu
# Processing Record 46 of Set 20 | kruisfontein
# Processing Record 47 of Set 20 | itoman
# Processing Record 48 of Set 20 | marzuq
# Processing Record 49 of Set 20 | kenai
# Processing Record 50 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 21 | cherskiy
# Processing Record 2 of Set 21 | bredasdorp
# Processing Record 3 of Set 21 | faanui
# Processing Record 4 of Set 21 | pombas
# Processing Record 5 of Set 21 | sao filipe
# Processing Record 6 of Set 21 | baie-comeau
# Processing Record 7 of Set 21 | chokurdakh
# Processing Record 8 of Set 21 | the valley
# Processing Record 9 of Set 21 | laguna
# Processing Record 10 of Set 21 | kirakira
# Processing Record 11 of Set 21 | naze
# Processing Record 12 of Set 21 | kahului
# Processing Record 13 of Set 21 | demirci
# Processing Record 14 of Set 21 | vestmanna
# Processing Record 15 of Set 21 | brownwood
# Processing Record 16 of Set 21 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 21 | ambovombe
# Processing Record 18 of Set 21 | tomelloso
# Processing Record 19 of Set 21 | pulaski
# Processing Record 20 of Set 21 | panama city
# Processing Record 21 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 21 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 21 | cozumel
# Processing Record 24 of Set 21 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 21 | bathsheba
# Processing Record 26 of Set 21 | tilichiki
# Processing Record 27 of Set 21 | dolores
# Processing Record 28 of Set 21 | hay river
# Processing Record 29 of Set 21 | palasa
# Processing Record 30 of Set 21 | beringovskiy
# Processing Record 31 of Set 21 | hasaki
# Processing Record 32 of Set 21 | cliza
# Processing Record 33 of Set 21 | ketchikan
# Processing Record 34 of Set 21 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 21 | cerrito
# Processing Record 36 of Set 21 | port alfred
# Processing Record 37 of Set 21 | discovery bay
# Processing Record 38 of Set 21 | hofn
# Processing Record 39 of Set 21 | akcaabat
# Processing Record 40 of Set 21 | vieste
# Processing Record 41 of Set 21 | raudeberg
# Processing Record 42 of Set 21 | kudahuvadhoo
# Processing Record 43 of Set 21 | bousso
# Processing Record 44 of Set 21 | praia da vitoria
# Processing Record 45 of Set 21 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 21 | villa del rosario
# Processing Record 47 of Set 21 | copiapo
# Processing Record 48 of Set 21 | parras
# City not found. Skipping...
# Processing Record 49 of Set 21 | batagay-alyta
# Processing Record 50 of Set 21 | quatre cocos
# Processing Record 1 of Set 22 | tigil
# Processing Record 2 of Set 22 | saint-augustin
# Processing Record 3 of Set 22 | matameye
# City not found. Skipping...
# Processing Record 4 of Set 22 | simbahan
# Processing Record 5 of Set 22 | ponta delgada
# Processing Record 6 of Set 22 | yenagoa
# Processing Record 7 of Set 22 | muravlenko
# Processing Record 8 of Set 22 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 22 | ostrovnoy
# Processing Record 10 of Set 22 | singkang
# Processing Record 11 of Set 22 | marapanim
# Processing Record 12 of Set 22 | moose factory
# Processing Record 13 of Set 22 | vanimo
# Processing Record 14 of Set 22 | saint-leu
# Processing Record 15 of Set 22 | beloha
# Processing Record 16 of Set 22 | lagunas
# Processing Record 17 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 22 | havre-saint-pierre
# Processing Record 19 of Set 22 | berlevag
# Processing Record 20 of Set 22 | concordia
# Processing Record 21 of Set 22 | hailar
# Processing Record 22 of Set 22 | grand gaube
# Processing Record 23 of Set 22 | thunder bay
# Processing Record 24 of Set 22 | tura
# Processing Record 25 of Set 22 | bandarbeyla
# Processing Record 26 of Set 22 | shaoyang
# Processing Record 27 of Set 22 | saldanha
# Processing Record 28 of Set 22 | guayaramerin
# Processing Record 29 of Set 22 | payo
# Processing Record 30 of Set 22 | carbonia
# Processing Record 31 of Set 22 | avera
# Processing Record 32 of Set 22 | livramento
# Processing Record 33 of Set 22 | khalkhal
# Processing Record 34 of Set 22 | asfi
# Processing Record 35 of Set 22 | kieta
# Processing Record 36 of Set 22 | aquiraz
# Processing Record 37 of Set 22 | manyana
# Processing Record 38 of Set 22 | san policarpo
# Processing Record 39 of Set 22 | gryazovets
# Processing Record 40 of Set 22 | znamenskoye
# Processing Record 41 of Set 22 | vadso
# Processing Record 42 of Set 22 | calatayud
# Processing Record 43 of Set 22 | marsh harbour
# Processing Record 44 of Set 22 | doctor juan manuel frutos
# Processing Record 45 of Set 22 | vostok
# Processing Record 46 of Set 22 | hamilton
# Processing Record 47 of Set 22 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 22 | lasa
# Processing Record 49 of Set 22 | karratha
# ...
# Processing Record 18 of Set 24 | ocos
# Processing Record 19 of Set 24 | utica
# Processing Record 20 of Set 24 | sun prairie
# Processing Record 21 of Set 24 | altay
# Processing Record 22 of Set 24 | wanning
# Processing Record 23 of Set 24 | la primavera
# Processing Record 24 of Set 24 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 24 | muros
# Processing Record 26 of Set 24 | tessalit
# Processing Record 27 of Set 24 | torbay
# Processing Record 28 of Set 24 | visby
# Processing Record 29 of Set 24 | filingue
# Processing Record 30 of Set 24 | tam ky
# Processing Record 31 of Set 24 | talara
# Processing Record 32 of Set 24 | innisfail
# Processing Record 33 of Set 24 | sankt veit
# Processing Record 34 of Set 24 | lakes entrance
# Processing Record 35 of Set 24 | natal
# Processing Record 36 of Set 24 | gizo
# Processing Record 37 of Set 24 | touros
# Processing Record 38 of Set 24 | manta
# Processing Record 39 of Set 24 | athens
# Processing Record 40 of Set 24 | berezovyy
# Processing Record 41 of Set 24 | namanga
# Processing Record 42 of Set 24 | plettenberg bay
# Processing Record 43 of Set 24 | luderitz
# Processing Record 44 of Set 24 | mersing
# Processing Record 45 of Set 24 | camargo
# Processing Record 46 of Set 24 | pevek
# Processing Record 47 of Set 24 | iqaluit
# Processing Record 48 of Set 24 | martinsburg
# Processing Record 49 of Set 24 | bang khla
# Processing Record 50 of Set 24 | east london
# Processing Record 1 of Set 25 | lata
# Processing Record 2 of Set 25 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 25 | bata
# Processing Record 4 of Set 25 | suoyarvi
# Processing Record 5 of Set 25 | korgen
# Processing Record 6 of Set 25 | belyy yar
# Processing Record 7 of Set 25 | lannion
# Processing Record 8 of Set 25 | swan river
# Processing Record 9 of Set 25 | bogalusa
# Processing Record 10 of Set 25 | acapulco
# Processing Record 11 of Set 25 | tambacounda
# Processing Record 12 of Set 25 | nilokheri
# Processing Record 13 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 25 | derzhavinsk
# Processing Record 15 of Set 25 | novyye lyady
# Processing Record 16 of Set 25 | oriximina
# Processing Record 17 of Set 25 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 25 | gorom-gorom
# Processing Record 19 of Set 25 | mugur-aksy
# Processing Record 20 of Set 25 | hervey bay
# Processing Record 21 of Set 25 | gawler
# Processing Record 22 of Set 25 | barcelona
# Processing Record 23 of Set 25 | broome
# Processing Record 24 of Set 25 | camacha
# Processing Record 25 of Set 25 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 26 of Set 25 | lazaro cardenas
# Processing Record 27 of Set 25 | pueblo
# Processing Record 28 of Set 25 | tiksi
# Processing Record 29 of Set 25 | penzance
# Processing Record 30 of Set 25 | yakeshi
# Processing Record 31 of Set 25 | bilma
# Processing Record 32 of Set 25 | ugoofaaru
# Processing Record 33 of Set 25 | kajaani
# Processing Record 34 of Set 25 | gardan diwal
# City not found. Skipping...
# Processing Record 35 of Set 25 | mudigere
# Processing Record 36 of Set 25 | hokitika
# Processing Record 37 of Set 25 | trelew
# Processing Record 38 of Set 25 | fort nelson
# Processing Record 39 of Set 25 | mount isa
# Processing Record 40 of Set 25 | griffith
# Processing Record 41 of Set 25 | esperance
# Processing Record 42 of Set 25 | rochester
# Processing Record 43 of Set 25 | quesnel
# Processing Record 44 of Set 25 | erenhot
# Processing Record 45 of Set 25 | burnie
# Processing Record 46 of Set 25 | cap malheureux
# Processing Record 47 of Set 25 | zaysan
# Processing Record 48 of Set 25 | praia
# Processing Record 49 of Set 25 | biltine
# Processing Record 50 of Set 25 | tabou
# Processing Record 1 of Set 26 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 26 | gazanjyk
# Processing Record 3 of Set 26 | palora
# Processing Record 4 of Set 26 | tres arroyos
# Processing Record 5 of Set 26 | gdynia
# Processing Record 6 of Set 26 | mareeba
# Processing Record 7 of Set 26 | pokhara
# Processing Record 8 of Set 26 | poum
# Processing Record 9 of Set 26 | oksfjord
# Processing Record 10 of Set 26 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 26 | roald
# Processing Record 12 of Set 26 | san nicolas
# Processing Record 13 of Set 26 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 26 | dayong
# Processing Record 15 of Set 26 | severodvinsk
# Processing Record 16 of Set 26 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 26 | charters towers
# Processing Record 18 of Set 26 | nouakchott
# Processing Record 19 of Set 26 | bocas del toro
# Processing Record 20 of Set 26 | lensk
# Processing Record 21 of Set 26 | colac
# Processing Record 22 of Set 26 | harnosand
# Processing Record 23 of Set 26 | ozark
# Processing Record 24 of Set 26 | teguise
# Processing Record 25 of Set 26 | shelburne
# Processing Record 26 of Set 26 | paamiut
# Processing Record 27 of Set 26 | saint anthony
# Processing Record 28 of Set 26 | bow island
# Processing Record 29 of Set 26 | kyra
# Processing Record 30 of Set 26 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 26 | makakilo city
# Processing Record 32 of Set 26 | makrana
# Processing Record 33 of Set 26 | wewak
# Processing Record 34 of Set 26 | shablykino
# Processing Record 35 of Set 26 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 26 | mount darwin
# Processing Record 37 of Set 26 | diffa
# Processing Record 38 of Set 26 | port augusta
# Processing Record 39 of Set 26 | patrocinio
# Processing Record 40 of Set 26 | qaqortoq
# Processing Record 41 of Set 26 | methoni
# Processing Record 42 of Set 26 | ozimek
# Processing Record 43 of Set 26 | tombouctou
# Processing Record 44 of Set 26 | abu kamal
# Processing Record 45 of Set 26 | shar
# Processing Record 46 of Set 26 | staryy krym
# Processing Record 47 of Set 26 | blankenberge
# Processing Record 48 of Set 26 | thinadhoo
# Processing Record 49 of Set 26 | sobolevo
# Processing Record 50 of Set 26 | iwanai
# Processing Record 1 of Set 27 | boyolangu
# Processing Record 2 of Set 27 | hamadan
# Processing Record 3 of Set 27 | neiafu
# Processing Record 4 of Set 27 | phan thiet
# Processing Record 5 of Set 27 | panaba
# Processing Record 6 of Set 27 | tignere
# Processing Record 7 of Set 27 | kalevala
# Processing Record 8 of Set 27 | harindanga
# Processing Record 9 of Set 27 | santa marta
# Processing Record 10 of Set 27 | tateyama
# Processing Record 11 of Set 27 | beyneu
# Processing Record 12 of Set 27 | winchester
# Processing Record 13 of Set 27 | abbeville
# Processing Record 14 of Set 27 | aswan
# Processing Record 15 of Set 27 | qasigiannguit
# Processing Record 16 of Set 27 | aranos
# Processing Record 17 of Set 27 | horta
# Processing Record 18 of Set 27 | aksha
# Processing Record 19 of Set 27 | tighina
# Processing Record 20 of Set 27 | bafq
# Processing Record 21 of Set 27 | pandan
# Processing Record 22 of Set 27 | murgud
# Processing Record 23 of Set 27 | kaabong
# Processing Record 24 of Set 27 | college
# Processing Record 25 of Set 27 | talaya
# Processing Record 26 of Set 27 | vernon
# Processing Record 27 of Set 27 | dicabisagan
# Processing Record 28 of Set 27 | birobidzhan
# Processing Record 29 of Set 27 | saleilua
# City not found. Skipping...
# Processing Record 30 of Set 27 | bilibino
# Processing Record 31 of Set 27 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 27 | broken hill
# Processing Record 33 of Set 27 | lady frere
# Processing Record 34 of Set 27 | zubtsov
# Processing Record 35 of Set 27 | matagami
# Processing Record 36 of Set 27 | rivadavia
# Processing Record 37 of Set 27 | sabang
# Processing Record 38 of Set 27 | san juan
# Processing Record 39 of Set 27 | oistins
# Processing Record 40 of Set 27 | yerani
# City not found. Skipping...
# Processing Record 41 of Set 27 | makaha
# Processing Record 42 of Set 27 | mizdah
# Processing Record 43 of Set 27 | najran
# Processing Record 44 of Set 27 | dingle
# Processing Record 45 of Set 27 | cuauhtemoc
# Processing Record 46 of Set 27 | darhan
# Processing Record 47 of Set 27 | lahad datu
# Processing Record 48 of Set 27 | flinders
# Processing Record 49 of Set 27 | texarkana
# Processing Record 50 of Set 27 | cockburn town
# Processing Record 1 of Set 28 | morehead
# Processing Record 2 of Set 28 | haapiti
# Processing Record 3 of Set 28 | santiago de compostela
# Processing Record 4 of Set 28 | karatau
# Processing Record 5 of Set 28 | rovaniemi
# Processing Record 6 of Set 28 | port hedland
# Processing Record 7 of Set 28 | pangai
# Processing Record 8 of Set 28 | adrar
# Processing Record 9 of Set 28 | kaeo
# Processing Record 10 of Set 28 | lieksa
# Processing Record 11 of Set 28 | lalmohan
# Processing Record 12 of Set 28 | alekseyevka
# Processing Record 13 of Set 28 | khvastovichi
# Processing Record 14 of Set 28 | luba
# Processing Record 15 of Set 28 | saveh
# Processing Record 16 of Set 28 | formosa
# Processing Record 17 of Set 28 | bentiu
# Processing Record 18 of Set 28 | dongying
# Processing Record 19 of Set 28 | bukene
# Processing Record 20 of Set 28 | lhokseumawe
# Processing Record 21 of Set 28 | colon
# Processing Record 22 of Set 28 | urumqi
# Processing Record 23 of Set 28 | dong xoai
# Processing Record 24 of Set 28 | funtua
# Processing Record 25 of Set 28 | ormstown
# Processing Record 26 of Set 28 | oxapampa
# Processing Record 27 of Set 28 | praya
# Processing Record 28 of Set 28 | sakakah
# Processing Record 29 of Set 28 | high rock
# Processing Record 30 of Set 28 | kuhdasht
# Processing Record 31 of Set 28 | lenger
# Processing Record 32 of Set 28 | shubarkuduk
# Processing Record 33 of Set 28 | saint pete beach
# Processing Record 34 of Set 28 | maimon
# City not found. Skipping...
# Processing Record 35 of Set 28 | necochea
# Processing Record 36 of Set 28 | bawku
# Processing Record 37 of Set 28 | popondetta
# Processing Record 38 of Set 28 | shimoda
# Processing Record 39 of Set 28 | khani
# Processing Record 40 of Set 28 | bratsk
# Processing Record 41 of Set 28 | jaisinghnagar
# Processing Record 42 of Set 28 | dombarovskiy
# Processing Record 43 of Set 28 | port saint lucie
# Processing Record 44 of Set 28 | teruel
# Processing Record 45 of Set 28 | weiser
# Processing Record 46 of Set 28 | batsfjord
# Processing Record 47 of Set 28 | solnechnyy
# Processing Record 48 of Set 28 | north bend
# Processing Record 49 of Set 28 | rawson
# Processing Record 50 of Set 28 | chinsali
# Processing Record 1 of Set 29 | muromtsevo
# Processing Record 2 of Set 29 | isangel
# Processing Record 3 of Set 29 | bowen
# Processing Record 4 of Set 29 | arvika
# Processing Record 5 of Set 29 | tommot
# Processing Record 6 of Set 29 | hegang
# Processing Record 7 of Set 29 | mfou
# Processing Record 8 of Set 29 | maarianhamina
# Processing Record 9 of Set 29 | sarkand
# Processing Record 10 of Set 29 | radhanpur
# Processing Record 11 of Set 29 | kastamonu
# Processing Record 12 of Set 29 | luanda
# Processing Record 13 of Set 29 | atikokan
# Processing Record 14 of Set 29 | nazca
# Processing Record 15 of Set 29 | uyuni
# Processing Record 16 of Set 29 | xinzhi
# Processing Record 17 of Set 29 | kupang
# Processing Record 18 of Set 29 | baykit
# Processing Record 19 of Set 29 | camabatela
# Processing Record 20 of Set 29 | conceicao da barra
# Processing Record 21 of Set 29 | sheridan
# Processing Record 22 of Set 29 | saint-andre-avellin
# Processing Record 23 of Set 29 | pasighat
# Processing Record 24 of Set 29 | high prairie
# Processing Record 25 of Set 29 | udayagiri
# Processing Record 26 of Set 29 | punta alta
# Processing Record 27 of Set 29 | jaleswar
# Processing Record 28 of Set 29 | turukhansk
# Processing Record 29 of Set 29 | el sauce
# Processing Record 30 of Set 29 | kralendijk
# Processing Record 31 of Set 29 | effingham
# Processing Record 32 of Set 29 | sarahan
# Processing Record 33 of Set 29 | yurginskoye
# Processing Record 34 of Set 29 | kabinda
# Processing Record 35 of Set 29 | bosaso
# Processing Record 36 of Set 29 | burica
# City not found. Skipping...
# Processing Record 37 of Set 29 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 29 | akdepe
# Processing Record 39 of Set 29 | yinchuan
# Processing Record 40 of Set 29 | bulgan
# Processing Record 41 of Set 29 | katherine
# Processing Record 42 of Set 29 | sur
# Processing Record 43 of Set 29 | balkhash
# Processing Record 44 of Set 29 | balykshi
# Processing Record 45 of Set 29 | varanasi
# Processing Record 46 of Set 29 | alofi
# Processing Record 47 of Set 29 | newark
# Processing Record 48 of Set 29 | herat
# Processing Record 49 of Set 29 | bunog
# Processing Record 50 of Set 29 | alice springs
# Processing Record 1 of Set 30 | vaitape
# Processing Record 2 of Set 30 | seoul
# Processing Record 3 of Set 30 | medicine hat
# Processing Record 4 of Set 30 | ha noi
# Processing Record 5 of Set 30 | robertsport
# Processing Record 6 of Set 30 | presidencia roque saenz pena
# Processing Record 7 of Set 30 | hanko
# Processing Record 8 of Set 30 | vila
# Processing Record 9 of Set 30 | camacupa
# Processing Record 10 of Set 30 | ascension
# Processing Record 11 of Set 30 | tupik
# Processing Record 12 of Set 30 | crib point
# Processing Record 13 of Set 30 | merauke
# Processing Record 14 of Set 30 | wundanyi
# Processing Record 15 of Set 30 | mangrol
# Processing Record 16 of Set 30 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 30 | hirara
# Processing Record 18 of Set 30 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 30 | bud
# Processing Record 20 of Set 30 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 30 | paita
# Processing Record 22 of Set 30 | port antonio
# Processing Record 23 of Set 30 | puerto escondido
# Processing Record 24 of Set 30 | thurso
# Processing Record 25 of Set 30 | de-kastri
# Processing Record 26 of Set 30 | puerto madryn
# Processing Record 27 of Set 30 | tezu
# Processing Record 28 of Set 30 | itarema
# Processing Record 29 of Set 30 | pringsewu
# Processing Record 30 of Set 30 | kardymovo
# Processing Record 31 of Set 30 | butte
# Processing Record 32 of Set 30 | sudbury
# Processing Record 33 of Set 30 | pauini
# Processing Record 34 of Set 30 | trairi
# Processing Record 35 of Set 30 | lufilufi
# Processing Record 36 of Set 30 | komsomolskiy
# Processing Record 37 of Set 30 | chastoozerye
# City not found. Skipping...
# Processing Record 38 of Set 30 | moyo
# Processing Record 39 of Set 30 | gostilitsy
# Processing Record 40 of Set 30 | luwuk
# Processing Record 41 of Set 30 | la palma
# Processing Record 42 of Set 30 | iquitos
# Processing Record 43 of Set 30 | taboc
# Processing Record 44 of Set 30 | yerbogachen
# Processing Record 45 of Set 30 | prado
# Processing Record 46 of Set 30 | royan
# Processing Record 47 of Set 30 | hualmay
# Processing Record 48 of Set 30 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 30 | boa vista
# Processing Record 50 of Set 30 | ust-nera
# Processing Record 1 of Set 31 | willmar
# Processing Record 2 of Set 31 | varzea da palma
# Processing Record 3 of Set 31 | rio grande
# Processing Record 4 of Set 31 | santiago del estero
# Processing Record 5 of Set 31 | magole
# Processing Record 6 of Set 31 | ahipara
# Processing Record 7 of Set 31 | tarcau
# Processing Record 8 of Set 31 | antsohihy
# Processing Record 9 of Set 31 | cocula
# Processing Record 10 of Set 31 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 31 | novo cruzeiro
# Processing Record 12 of Set 31 | viedma
# Processing Record 13 of Set 31 | cascais
# Processing Record 14 of Set 31 | ranong
# Processing Record 15 of Set 31 | shache
# Processing Record 16 of Set 31 | ellsworth
# Processing Record 17 of Set 31 | kaohsiung
# Processing Record 18 of Set 31 | benatky nad jizerou
# Processing Record 19 of Set 31 | khamgaon
# Processing Record 20 of Set 31 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 31 | acajutla
# Processing Record 22 of Set 31 | sorland
# Processing Record 23 of Set 31 | nakamura
# Processing Record 24 of Set 31 | debre sina
# Processing Record 25 of Set 31 | pakxan
# Processing Record 26 of Set 31 | maicao
# Processing Record 27 of Set 31 | sept-iles
# Processing Record 28 of Set 31 | brae
# Processing Record 29 of Set 31 | bangkalan
# Processing Record 30 of Set 31 | lima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 723

# %%
city_data[1]
# Out:
# {'City': 'Obo',
#  'Country': 'CF',
#  'Lat': 5.3998,
#  'Lng': 26.4869,
#  'Max Temp': 67.8,
#  'Humidity': 96,
#  'Cloudiness': 100,
#  'Wind Speed': 2.26,
#  'Current Weather': 'overcast clouds'}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.all()
# Out:
# City                True
# Country             True
# Lat                 True
# Lng                 True
# Max Temp            True
# Humidity            True
# Cloudiness         False
# Wind Speed         False
# Current Weather     True
# dtype: bool

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Sola      VU -13.8833  167.5500     79.43        79          37
# 1            Obo      CF   5.3998   26.4869     67.80        96         100
# 2       Hermanus      ZA -34.4187   19.2345     51.91        68          99
# 3    Provideniya      RU  64.3833 -173.3000     50.11        81          90
# 4         Khotyn      UA  48.4833   26.5000     71.20        69          12
# ..           ...     ...      ...       ...       ...       ...         ...
# 718       Maicao      CO  11.3832  -72.2432     80.04        79          36
# 719    Sept-Iles      CA  50.2001  -66.3821     61.05        72          75
# 720         Brae      GB  60.3964   -1.3530     55.31        95          99
# 721    Bangkalan      ID  -7.0455  112.7351     87.75        66           6
# 722         Lima      PE -12.0432  -77.0282     61.05        88          90
#
#      Wind Speed   Current Weather
# 0         22.70  scattered clouds
# 1          2.26   overcast clouds
# 2         13.33   overcast clouds
# 3         15.66     moderate rain
# 4          3.69        few clouds
# ..          ...               ...
# 718       11.48  scattered clouds
# 719        7.00     broken clouds
# 720        6.13   overcast clouds
# 721        1.12         clear sky
# 722       12.66   overcast clouds
#
# [723 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
